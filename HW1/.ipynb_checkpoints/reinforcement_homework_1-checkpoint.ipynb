# %% [markdown]
# # Reinforcement learning from scratch: homework 1

# %% [markdown]
# ## Andrew SaLoutos, April 30 2018
#
# ## EECS 495, Reinforcement Learning
#
# ## Homework 1 (completed iPython notebook)

# %% [markdown]
# ### General instructions
#
# Complete the exericse listed below in this Jupyter notebook - leaving all of your code in Python cells in the notebook itself.  Feel free to add any necessary cells.

# %% [markdown]
# ### When submitting this homework:
#
# **Make sure you have put your name at the top of each file**
#
# **Make sure all output is present in your notebook prior to submission**

# %%
# import custom libraries
from custom_library import basic_optimizers as optimizers
from custom_library import variable_order_plotters as plotter

# import autograd functionality
import autograd.numpy as np

# import path to datasets
datapath = 'datasets/'

# this is needed to compensate for %matplotl+ib notebook's tendancy to blow up images when plotted inline
from matplotlib import rcParams
rcParams['figure.autolayout'] = True
# %matplotlib notebook

# autoreload function - so if anything behind the scenes is changeed those changes
# are reflected in the notebook without having to restart the kernel
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 1: </span>  Perform system identification on a small chunk of cruise control data

# %% [markdown]
# In this exercise you will create a system model - denoted as $f_{\text{system}}$ in the [course notes](https://www.dropbox.com/s/m6456ze0fd8kaf8/system_identification_pid_notes.pdf?dl=0) - using a small snippet of cruise control data shown below.  Here our `output sequence` are states $\left\{s_t\right\}_{t=1}^T$, and the `input sequence` corresponding actions $\left\{a_t\right\}_{t=1}^{T-1}$ (we can ignore any finanl action $a_T$ since there is no next state $s_{t+1}$ to regress it on in learning our system model).  Notice at each update step the action is clipped to lie in the range $[-50,100]$ - which is the angle of the pedal against the floor of the car.  Here a negative angle indicates that 'regenerative braking' was applied.

# %%
# load in cruise control data
data = np.loadtxt(datapath + 'cruise_control_data.csv',delimiter = ',')

# extract actions and states 
actions = data[0,1:][np.newaxis,:] # our T-1 actions
states = data[1,:][np.newaxis,:]   # our T states

# plot the test pair
plotter.plot_pair(actions,states)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Some more particulars: here you need to learn the weights of a basic order $1$ linear system model - which takes the form
#
# \begin{equation}
# s_{t+1} = f_{\text{system}}\left(s_t,a_t; \mathbf{w}_\text{system}\right) = w_0 + w_1s_t + w_2a_t
# \end{equation}
#
# by properly minimizing the associated Least Squares cost function
#
# \begin{equation}
# \frac{1}{T-1}\sum_{t=1}^{T-1}\left(f_{\text{system}}\left(s_t,a_t; \mathbf{w}_\text{system}\right) - s_{t+1}\right)^2
# \end{equation}
#
# over the weights $\mathbf{w}_{\text{system}} = \begin{bmatrix} w_0 \\ w_1 \\ w_2 \end{bmatrix}$ where $T$ is the length of our training action sequence.
#
#
# - Build a `Python` version of the system model and Least Squares cost function and minimize it using a first order method.  Use the entire dataset provided for training (i.e., do not worry about validation error)
#
#
# - A simple full batch gradient descent module has been provided in file file `basic_optimizers.py` in the `custom_library` directory for use with this exercise.
#
#
# - After properly minimizing the Least Squares cost above make a plot like the one shown below - which shows the original state data in black, and the system model approximation in blue.  Your trained model should be able to match the data quite well.

# %% [raw]
# <figure>
# <p>
# <img src= 'images/system_id_1.png' width="150%" height="150%" alt=""/>
# </p>
# </figure>

# %%
### system model

def g(w,a_train,s_train):
    ''' Least squares cost function '''
    
    J = 0
    
    T = s_train.shape[1]
    
    for ii in range(1,T-1):
        J = J + (w[0] + w[1]*s_train[0,ii] + w[2]*a_train[0,ii] - s_train[0,ii+1])**2
    
    J = J/(T-1)
    
    return J    

### minimize the least squares (using entire dataset) using full-batch gradient descent
weights = np.random.rand(3,1)

alpha = 0.00025
max_its = 500
verbose = True


w_hist,train_hist = optimizers.gradient_descent(g,weights,actions,states,alpha,max_its,verbose)
# Out:
# step 2 done in 0.4 secs, train cost = 193.0067
# step 3 done in 0.3 secs, train cost = 164.3331
# step 4 done in 0.3 secs, train cost = 139.9335
# step 5 done in 0.3 secs, train cost = 119.1683
# step 6 done in 0.3 secs, train cost = 101.4939
# step 7 done in 0.3 secs, train cost = 86.4487
# step 8 done in 0.3 secs, train cost = 73.6401
# step 9 done in 0.3 secs, train cost = 62.7347
# step 10 done in 0.3 secs, train cost = 53.4487
# step 11 done in 0.3 secs, train cost = 45.541
# step 12 done in 0.3 secs, train cost = 38.8066
# step 13 done in 0.3 secs, train cost = 33.0708
# step 14 done in 0.3 secs, train cost = 28.1854
# step 15 done in 0.3 secs, train cost = 24.0239
# step 16 done in 0.4 secs, train cost = 20.4788
# step 17 done in 0.3 secs, train cost = 17.4588
# step 18 done in 0.3 secs, train cost = 14.8858
# step 19 done in 0.3 secs, train cost = 12.6936
# step 20 done in 0.3 secs, train cost = 10.8258
# step 21 done in 0.3 secs, train cost = 9.2344
# step 22 done in 0.3 secs, train cost = 7.8782
# step 23 done in 0.3 secs, train cost = 6.7226
# step 24 done in 0.4 secs, train cost = 5.7379
# step 25 done in 0.3 secs, train cost = 4.8987
# step 26 done in 0.4 secs, train cost = 4.1835
# step 27 done in 0.4 secs, train cost = 3.574
# step 28 done in 0.3 secs, train cost = 3.0545
# step 29 done in 0.3 secs, train cost = 2.6118
# step 30 done in 0.4 secs, train cost = 2.2345
# step 31 done in 0.3 secs, train cost = 1.9129
# step 32 done in 0.4 secs, train cost = 1.6388
# step 33 done in 0.3 secs, train cost = 1.4051
# step 34 done in 0.4 secs, train cost = 1.206
# step 35 done in 0.2 secs, train cost = 1.0362
# step 36 done in 0.4 secs, train cost = 0.8915
# step 37 done in 0.3 secs, train cost = 0.7682
# step 38 done in 0.3 secs, train cost = 0.6631
# step 39 done in 0.3 secs, train cost = 0.5734
# step 40 done in 0.3 secs, train cost = 0.4971
# step 41 done in 0.3 secs, train cost = 0.4319
# step 42 done in 0.3 secs, train cost = 0.3764
# step 43 done in 0.3 secs, train cost = 0.3291
# step 44 done in 0.2 secs, train cost = 0.2888
# step 45 done in 0.3 secs, train cost = 0.2544
# step 46 done in 0.3 secs, train cost = 0.2251
# step 47 done in 0.4 secs, train cost = 0.2001
# step 48 done in 0.3 secs, train cost = 0.1788
# step 49 done in 0.4 secs, train cost = 0.1606
# step 50 done in 0.3 secs, train cost = 0.1451
# step 51 done in 0.3 secs, train cost = 0.1319
# step 52 done in 0.4 secs, train cost = 0.1207
# step 53 done in 0.4 secs, train cost = 0.1111
# step 54 done in 0.4 secs, train cost = 0.1029
# step 55 done in 0.3 secs, train cost = 0.0959
# step 56 done in 0.4 secs, train cost = 0.09
# step 57 done in 0.4 secs, train cost = 0.0849
# step 58 done in 0.3 secs, train cost = 0.0806
# step 59 done in 0.3 secs, train cost = 0.0769
# step 60 done in 0.3 secs, train cost = 0.0738
# step 61 done in 0.3 secs, train cost = 0.0711
# step 62 done in 0.4 secs, train cost = 0.0688
# step 63 done in 0.4 secs, train cost = 0.0669
# step 64 done in 0.3 secs, train cost = 0.0652
# step 65 done in 0.3 secs, train cost = 0.0638
# step 66 done in 0.3 secs, train cost = 0.0626
# step 67 done in 0.2 secs, train cost = 0.0616
# step 68 done in 0.3 secs, train cost = 0.0607
# step 69 done in 0.3 secs, train cost = 0.06
# step 70 done in 0.3 secs, train cost = 0.0593
# step 71 done in 0.3 secs, train cost = 0.0588
# step 72 done in 0.2 secs, train cost = 0.0583
# step 73 done in 0.3 secs, train cost = 0.0579
# step 74 done in 0.3 secs, train cost = 0.0576
# step 75 done in 0.4 secs, train cost = 0.0573
# step 76 done in 0.3 secs, train cost = 0.0571
# step 77 done in 0.3 secs, train cost = 0.0569
# step 78 done in 0.3 secs, train cost = 0.0567
# step 79 done in 0.4 secs, train cost = 0.0565
# step 80 done in 0.4 secs, train cost = 0.0564
# step 81 done in 0.4 secs, train cost = 0.0563
# step 82 done in 0.3 secs, train cost = 0.0562
# step 83 done in 0.4 secs, train cost = 0.0561
# step 84 done in 0.4 secs, train cost = 0.056
# step 85 done in 0.4 secs, train cost = 0.056
# step 86 done in 0.3 secs, train cost = 0.0559
# step 87 done in 0.4 secs, train cost = 0.0559
# step 88 done in 0.3 secs, train cost = 0.0559
# step 89 done in 0.3 secs, train cost = 0.0558
# step 90 done in 0.4 secs, train cost = 0.0558
# step 91 done in 0.4 secs, train cost = 0.0558
# step 92 done in 0.3 secs, train cost = 0.0558
# step 93 done in 0.4 secs, train cost = 0.0557
# step 94 done in 0.3 secs, train cost = 0.0557
# step 95 done in 0.3 secs, train cost = 0.0557
# step 96 done in 0.3 secs, train cost = 0.0557
# step 97 done in 0.3 secs, train cost = 0.0557
# step 98 done in 0.3 secs, train cost = 0.0557
# step 99 done in 0.3 secs, train cost = 0.0557
# step 100 done in 0.4 secs, train cost = 0.0557
# step 101 done in 0.4 secs, train cost = 0.0557
# step 102 done in 0.3 secs, train cost = 0.0557
# step 103 done in 0.3 secs, train cost = 0.0557
# step 104 done in 0.3 secs, train cost = 0.0557
# step 105 done in 0.3 secs, train cost = 0.0557
# step 106 done in 0.3 secs, train cost = 0.0557
# step 107 done in 0.3 secs, train cost = 0.0557
# step 108 done in 0.4 secs, train cost = 0.0557
# step 109 done in 0.3 secs, train cost = 0.0557
# step 110 done in 0.4 secs, train cost = 0.0557
# step 111 done in 0.3 secs, train cost = 0.0557
# step 112 done in 0.3 secs, train cost = 0.0557
# step 113 done in 0.3 secs, train cost = 0.0557
# step 475 done in 0.3 secs, train cost = 0.0556
# step 476 done in 0.3 secs, train cost = 0.0556
# step 477 done in 0.3 secs, train cost = 0.0556
# step 478 done in 0.2 secs, train cost = 0.0556
# step 479 done in 0.3 secs, train cost = 0.0556
# step 480 done in 0.3 secs, train cost = 0.0556
# step 481 done in 0.3 secs, train cost = 0.0556
# step 482 done in 0.2 secs, train cost = 0.0556
# step 483 done in 0.3 secs, train cost = 0.0556
# step 484 done in 0.4 secs, train cost = 0.0556
# step 485 done in 0.3 secs, train cost = 0.0556
# step 486 done in 0.4 secs, train cost = 0.0556
# step 487 done in 0.3 secs, train cost = 0.0556
# step 488 done in 0.3 secs, train cost = 0.0556
# step 489 done in 0.3 secs, train cost = 0.0556
# step 490 done in 0.3 secs, train cost = 0.0556
# step 491 done in 0.4 secs, train cost = 0.0556
# step 492 done in 0.3 secs, train cost = 0.0556
# step 493 done in 0.4 secs, train cost = 0.0556
# step 494 done in 0.4 secs, train cost = 0.0556
# step 495 done in 0.3 secs, train cost = 0.0556
# step 496 done in 0.3 secs, train cost = 0.0556
# step 497 done in 0.4 secs, train cost = 0.0556
# step 498 done in 0.4 secs, train cost = 0.0556
# step 499 done in 0.3 secs, train cost = 0.0556
# step 500 done in 0.4 secs, train cost = 0.0556
# step 501 done in 0.4 secs, train cost = 0.0556
# finished all 500 steps

# %%
### plot original state data and system model approximation

# evaluate output of learned model
opt_weights = w_hist[-1]
print(opt_weights)    # cost of 0.0556; weights = [0.7749408, 0.9390561, 0.03648759]

T = states.shape[1]
system_model = np.zeros(T-1)
    
for ii in range(1,T-1):
    system_model[ii] = opt_weights[0] + opt_weights[1]*states[0,ii-1] + opt_weights[2]*actions[0,ii]


import matplotlib.pyplot as plt
from matplotlib import gridspec
import copy

# initialize figure
fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(111); 

# plot data
ax1.plot(np.arange(np.size(system_model)),system_model.flatten(),c = 'cyan',linewidth = 1.5,label = 'System Model',zorder = 2)
ax1.plot(np.arange(np.size(states)),states.flatten(),c = 'black',linewidth = 1.5,label = 'Original States',zorder = 1)

# label axes and title
ax1.set_title('Output Sequences')
ax1.set_xlabel('Step')

plt.show()
# Out:
# [0.7749408, 0.9390561, 0.03648759]
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 2: </span>  Train an unregularized PID controller for the cruise control problem

# %% [markdown]
# In this exercise you will tune the parameters of a PID controller automatically so that the system model trained in the previous exercise matches the example set point sequence shown below.  Note: you need to have finished the previous exercise in order to properly solve this one!

# %%
# load in set point sequence
csvname = 'datasets/cruise_setpoints.csv'
set_points = np.loadtxt(csvname,delimiter = ',')[np.newaxis,:]

# plot set point sequence
plotter.plot_setpoints(set_points)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Implement a `Pythonic` version of the PID controller Least Squares cost function discussed in the [course notes](https://www.dropbox.com/s/m6456ze0fd8kaf8/system_identification_pid_notes.pdf?dl=0).  You should be able to learn an action / state sequence pair so that your system model responds fairly well to the input set point sequence.  The image below shows the results of an action/state sequence pair learned by a fully tuned PID controller.  The top panel shows the set point sequence in dashed black, with the state sequence defined by the controller in blue.  The bottom panel shows the corresponding action sequence defined by the controller.
#
# A few notes:
# - For this exercise you need not worry about regularizing either the state or action sequences when training the controller - simply tune it as best as you can.
#
#
# - Even though a PID controller is technically a Recurrent Network (which can be slow to train), here we only deal with a fairly small dataset of set points and there only 4 parameters to tune - so you can apply the simplest kind of first order algorithm to properly minimize the controller cost (e.g., a full batch gradient descent optimizer).

# %% [markdown]
# <figure>
# <p>
# <img src= 'images/PID_1.png' width="150%" height="150%" alt=""/>
# </p>
# </figure>

# %%
# inner loop gradient descent function to tune weights

V = [0.7749408, 0.9390561, 0.03648759] # optimal weights for system model, from problem 1


def g(w,a_train,s_train):
    ''' 
    Least squares cost function 

    Incorporating PID weights into system model

    '''
    
    J = 0
    T = set_points.shape[1]
    dt = 1 # time is given in "steps"
    
    Perror = 0
    Ierror = 0
    Derror = 0
    last_error = 0
    
    action = 0
    state = 0    
    last_action = 0
    last_state = 0
    
    for ii in range(1,T-1):
        
        Perror = s_train[0,ii] - last_state
        Ierror = Ierror + (dt)*Perror
        Derror = (Perror - last_error) / dt
        
        action = w[0] + w[1]*Perror + w[2]*Ierror + w[3]*Derror # current action from PID controller
        if (action>100.0):
            action = 100.0
        if (action<-50.0):
            action = -50.0
        state = V[0] + V[1]*last_state + V[2]*last_action # current state from system model
              
        J = J + (V[0] + V[1]*state + V[2]*action - s_train[0,ii+1])**2
        
        last_state = state
        last_action = action
        last_error = Perror
    
    J = J/(T-1)
    
    return J    

# optimize PID weights
alpha = 0.01
max_its = 500
verbose = True
PIDweights = [1.0,10.0,1.0,1.0]

PIDw_hist, train_hist = optimizers.gradient_descent(g,PIDweights,[],set_points,alpha,max_its,verbose)

print(PIDw_hist[-1])
# Out:
# step 2 done in 0.5 secs, train cost = 17.2891
# step 3 done in 0.5 secs, train cost = 16.9993
# step 4 done in 0.5 secs, train cost = 16.7171
# step 5 done in 0.5 secs, train cost = 16.4207
# step 6 done in 0.5 secs, train cost = 16.1017
# step 7 done in 0.4 secs, train cost = 15.7808
# step 8 done in 0.4 secs, train cost = 15.4557
# step 9 done in 0.5 secs, train cost = 15.1334
# step 10 done in 0.4 secs, train cost = 14.8228
# step 11 done in 0.3 secs, train cost = 14.5332
# step 12 done in 0.5 secs, train cost = 14.2726
# step 13 done in 0.5 secs, train cost = 14.05
# step 14 done in 0.5 secs, train cost = 13.8682
# step 15 done in 0.3 secs, train cost = 13.7257
# step 16 done in 0.4 secs, train cost = 13.6157
# step 17 done in 0.4 secs, train cost = 13.5325
# step 18 done in 0.3 secs, train cost = 13.4651
# step 19 done in 0.4 secs, train cost = 13.412
# step 20 done in 0.4 secs, train cost = 13.3659
# step 21 done in 0.5 secs, train cost = 13.319
# step 22 done in 0.5 secs, train cost = 13.2681
# step 23 done in 0.5 secs, train cost = 13.2152
# step 24 done in 0.5 secs, train cost = 13.1558
# step 25 done in 0.6 secs, train cost = 13.1175
# step 26 done in 0.5 secs, train cost = 13.1166
# step 27 done in 0.4 secs, train cost = 13.1164
# step 451 done in 0.3 secs, train cost = 13.0489
# step 452 done in 0.4 secs, train cost = 13.0488
# step 453 done in 0.4 secs, train cost = 13.0487
# step 454 done in 0.6 secs, train cost = 13.0485
# step 455 done in 0.4 secs, train cost = 13.0484
# step 456 done in 0.4 secs, train cost = 13.0483
# step 457 done in 0.6 secs, train cost = 13.0481
# step 458 done in 0.3 secs, train cost = 13.048
# step 459 done in 0.5 secs, train cost = 13.0479
# step 460 done in 0.5 secs, train cost = 13.0477
# step 461 done in 0.5 secs, train cost = 13.0476
# step 462 done in 0.6 secs, train cost = 13.0475
# step 463 done in 0.4 secs, train cost = 13.0473
# step 464 done in 0.4 secs, train cost = 13.0472
# step 465 done in 0.3 secs, train cost = 13.0471
# step 466 done in 0.4 secs, train cost = 13.0469
# step 467 done in 0.4 secs, train cost = 13.0468
# step 468 done in 0.6 secs, train cost = 13.0467
# step 469 done in 0.3 secs, train cost = 13.0465
# step 470 done in 0.5 secs, train cost = 13.0464
# step 471 done in 0.5 secs, train cost = 13.0462
# step 472 done in 0.5 secs, train cost = 13.0461
# step 473 done in 0.5 secs, train cost = 13.046
# step 474 done in 0.5 secs, train cost = 13.0458
# step 475 done in 0.5 secs, train cost = 13.0457
# step 476 done in 0.5 secs, train cost = 13.0456
# step 477 done in 0.5 secs, train cost = 13.0454
# step 478 done in 0.5 secs, train cost = 13.0453
# step 479 done in 0.4 secs, train cost = 13.0452
# step 480 done in 0.5 secs, train cost = 13.0451
# step 481 done in 0.4 secs, train cost = 13.0449
# step 482 done in 0.5 secs, train cost = 13.0448
# step 483 done in 0.5 secs, train cost = 13.0447
# step 484 done in 0.5 secs, train cost = 13.0445
# step 485 done in 0.4 secs, train cost = 13.0444
# step 486 done in 0.5 secs, train cost = 13.0443
# step 487 done in 0.5 secs, train cost = 13.0441
# step 488 done in 0.5 secs, train cost = 13.044
# step 489 done in 0.5 secs, train cost = 13.0439
# step 490 done in 0.5 secs, train cost = 13.0437
# step 491 done in 0.5 secs, train cost = 13.0436
# step 492 done in 0.5 secs, train cost = 13.0435
# step 493 done in 0.4 secs, train cost = 13.0433
# step 494 done in 0.5 secs, train cost = 13.0432
# step 495 done in 0.5 secs, train cost = 13.0431
# step 496 done in 0.5 secs, train cost = 13.0429
# step 497 done in 0.5 secs, train cost = 13.0428
# step 498 done in 0.5 secs, train cost = 13.0427
# step 499 done in 0.5 secs, train cost = 13.0425
# step 500 done in 0.5 secs, train cost = 13.0424
# step 501 done in 0.5 secs, train cost = 13.0423
# finished all 500 steps
# [array(1.13983968), array(10.60205147), array(0.00964514), array(0.97730439)]

# %%
# use optimized weights to calculate response to set points trajectory
opt_PIDw = PIDw_hist[-1] 
# one output of optimization: [array(1.13983968), array(10.60205147), array(0.00964514), array(0.97730439)], cost of 13.0423

T = set_points.shape[1]

states = np.zeros(T)
actions = np.zeros(T)

dt = 1 # time is given in "steps"
    
Perror = 0
Ierror = 0
Derror = 0
last_error = 0
 
last_action = 0
last_state = 0

for ii in range(1,T-1):

    Perror = set_points[0,ii] - last_state
    Ierror = Ierror + (dt)*Perror
    Derror = (Perror - last_error) / dt

    actions[ii] = opt_PIDw[0] + opt_PIDw[1]*Perror + opt_PIDw[2]*Ierror + opt_PIDw[3]*Derror # current action from PID controller
    if (actions[ii]<-50.0):
        actions[ii]=-50.0
    if (actions[ii]>100.0):
        actions[ii]=100.0    
    states[ii+1] = V[0] + V[1]*last_state + V[2]*actions[ii] # current state from system model

    last_state = states[ii]
    last_action = actions[ii]
    last_error = Perror


# plot output of PID controller here
import matplotlib.pyplot as plt
from matplotlib import gridspec
import copy

# initialize figure
fig = plt.figure(figsize = (10,5))

# create subplot with 3 panels, plot input function in center plot
gs = gridspec.GridSpec(2,1) 
ax1 = plt.subplot(gs[1]); 
ax2 = plt.subplot(gs[0]);

ax1.plot(np.arange(np.size(actions)),actions.flatten(),c = 'lime',linewidth = 1.5)
ax2.plot(np.arange(np.size(states)),states.flatten(),c = 'cyan',linewidth = 1.5,label = 'States',zorder = 2)
ax2.plot(np.arange(np.size(set_points)),set_points.flatten(),c = 'k',linewidth = 1.5,label = 'Set Points',zorder = 1)

# label axes and title
ax1.set_title('input sequence')
ax1.set_xlabel('step')
ax2.set_title('output sequences')
ax2.set_xlabel('step')

# set viewing limits
s1min = np.min(copy.deepcopy(actions))
s1max = np.max(copy.deepcopy(actions))
s1gap = (s1max - s1min)*0.1
s1min -= s1gap
s1max += s1gap
ax1.set_ylim([s1min,s1max])

s2min = np.min(copy.deepcopy(states))
s2max = np.max(copy.deepcopy(states))
s2gap = (s2max - s2min)*0.1
s2min -= s2gap
s2max += s2gap
ax2.legend(loc = 1)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 3: </span>  System identification on the two-tank problem

# %% [markdown]
# In this exercise you will create a system model - using a small snippet of cruise control data shown below.  This comes from a real life two-tanks experiment as shown on page 4 of the [course notes](https://www.dropbox.com/s/m6456ze0fd8kaf8/system_identification_pid_notes.pdf?dl=0).  The amount of water allowed into the top tank (per second) - the action sequence $a_t$ - is shown as the black curve in the bottom panel.  In the top panel the *upper* tank water level $s_{1,t}$ is shown in green, and the bottom tank level $s_{2,t}$ is shown in magenta.

# %%
# This code cell will not be shown in the HTML version of this notebook
# load series
data = np.loadtxt(datapath + 'cascaded_tanks_1.csv',delimiter = ',')
actions = data[0:1,1:]
states = data[1:,:]

# plot the test pair
plotter.plot_3fer(actions,states[0],states[1],plot_type = 'continuous')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# This system has two $s_{1,t}$ and $s_{2,t}$, hence the system model consists of an equation for each.  The upper tank level $s_{1,t}$ is dependent on its own history and - of course- the amount of water $a_t$ that is poured into it.  A simple linear system model for it then looks like
#
# \begin{equation}
# s_{1,t+1} = w_0 + w_1 s_{1,t} + w_2 a_t.
# \end{equation}
#
# Since we know that the upper tank drains into the lower one, the simplest sort of system model we can make for the lower tank level $s_{2,t}$ is that it is proportional to its prior value and that of the upper tank, as
#
# \begin{equation}
# s_{2,t+1} = w_3 + w_4s_{2,t} + w_5 s_{1,t}.
# \end{equation}
#
# Together - using the simplest model for this system we could think of - we have the following two system model equations
#
# \begin{array}
# \
# s_{1,t+1} = w_0 + w_1 s_{1,t} + w_2 a_t \\
# s_{2,t+1} = w_3 + w_4s_{2,t} + w_5 s_{1,t}.
# \end{array}

# %% [markdown]
# Tune the parameters of this system model $w_0$ through $w_5$ via minimizing a Least Squares cost function, using the data shown above for training (i.e., you need not cut off a chunk of it for validation - use it all for training).  Make sure to plot the fit your model provides on the training data.  You can see this exact system model fit to this exact dataset in the course notes - make sure your fit looks fairly similar.

# %%
# least squares function

def g(w,a_train,s_train):
    ''' Least squares cost function'''
    
    J1 = 0
    J2 = 0
    T = s_train.shape[1]
    
    for ii in range(1,T-1):
        J1 = J1 + (w[0] + w[1]*s_train[0,ii] + w[2]*a_train[0,ii] - s_train[0,ii+1])**2 # cost for first tank
        J2 = J2 + (w[3] + w[4]*s_train[1,ii] + w[5]*s_train[0,ii] - s_train[1,ii+1])**2

    J = (J1+J2)/(T-1)

    return J

# gradient descent

weights = np.random.rand(6,1)

alpha = 0.025
max_its = 200
verbose = True

w_hist,train_hist = optimizers.gradient_descent(g,weights,actions,states,alpha,max_its,verbose)

print(w_hist[-1])
# Out:
# step 2 done in 1.3 secs, train cost = 1.2452
# step 3 done in 1.3 secs, train cost = 1.119
# step 4 done in 1.3 secs, train cost = 1.0634
# step 5 done in 1.3 secs, train cost = 1.0135
# step 6 done in 1.4 secs, train cost = 0.9662
# step 7 done in 1.4 secs, train cost = 0.9213
# step 8 done in 1.4 secs, train cost = 0.8787
# step 9 done in 1.4 secs, train cost = 0.8383
# step 10 done in 1.4 secs, train cost = 0.7999
# step 11 done in 1.3 secs, train cost = 0.7634
# step 12 done in 1.3 secs, train cost = 0.7288
# step 13 done in 1.5 secs, train cost = 0.6958
# step 14 done in 1.3 secs, train cost = 0.6645
# step 15 done in 1.4 secs, train cost = 0.6348
# step 16 done in 1.3 secs, train cost = 0.6066
# step 17 done in 1.4 secs, train cost = 0.5797
# step 18 done in 1.3 secs, train cost = 0.5542
# step 19 done in 1.0 secs, train cost = 0.5299
# step 20 done in 1.1 secs, train cost = 0.5068
# step 21 done in 0.9 secs, train cost = 0.4848
# step 22 done in 1.1 secs, train cost = 0.4639
# step 23 done in 1.2 secs, train cost = 0.444
# step 24 done in 1.2 secs, train cost = 0.4251
# step 25 done in 1.0 secs, train cost = 0.4071
# step 26 done in 1.2 secs, train cost = 0.3899
# step 27 done in 1.1 secs, train cost = 0.3736
# step 28 done in 1.4 secs, train cost = 0.3581
# step 29 done in 1.1 secs, train cost = 0.3433
# step 30 done in 1.1 secs, train cost = 0.3291
# step 31 done in 1.0 secs, train cost = 0.3157
# step 32 done in 1.2 secs, train cost = 0.3029
# step 33 done in 1.2 secs, train cost = 0.2907
# step 34 done in 1.0 secs, train cost = 0.279
# step 35 done in 0.9 secs, train cost = 0.2679
# step 36 done in 1.2 secs, train cost = 0.2573
# step 37 done in 1.2 secs, train cost = 0.2472
# step 38 done in 1.2 secs, train cost = 0.2376
# step 39 done in 1.1 secs, train cost = 0.2284
# step 40 done in 1.4 secs, train cost = 0.2196
# step 41 done in 1.2 secs, train cost = 0.2112
# step 42 done in 1.0 secs, train cost = 0.2032
# step 43 done in 1.1 secs, train cost = 0.1956
# step 44 done in 1.1 secs, train cost = 0.1882
# step 45 done in 1.1 secs, train cost = 0.1813
# step 46 done in 1.2 secs, train cost = 0.1746
# step 47 done in 1.2 secs, train cost = 0.1682
# step 48 done in 0.9 secs, train cost = 0.1621
# step 49 done in 1.2 secs, train cost = 0.1563
# step 50 done in 1.3 secs, train cost = 0.1507
# step 51 done in 1.0 secs, train cost = 0.1453
# step 52 done in 1.0 secs, train cost = 0.1402
# step 53 done in 1.2 secs, train cost = 0.1353
# step 54 done in 1.1 secs, train cost = 0.1306
# step 55 done in 1.2 secs, train cost = 0.1262
# step 56 done in 1.0 secs, train cost = 0.1219
# step 57 done in 0.9 secs, train cost = 0.1177
# step 58 done in 1.1 secs, train cost = 0.1138
# step 59 done in 1.0 secs, train cost = 0.11
# step 60 done in 0.8 secs, train cost = 0.1064
# step 61 done in 1.1 secs, train cost = 0.1029
# step 62 done in 1.3 secs, train cost = 0.0995
# step 63 done in 1.3 secs, train cost = 0.0963
# step 64 done in 1.3 secs, train cost = 0.0932
# step 65 done in 1.3 secs, train cost = 0.0903
# step 66 done in 1.2 secs, train cost = 0.0875
# step 67 done in 1.1 secs, train cost = 0.0847
# step 68 done in 1.1 secs, train cost = 0.0821
# step 69 done in 1.0 secs, train cost = 0.0796
# step 70 done in 1.3 secs, train cost = 0.0772
# step 71 done in 1.3 secs, train cost = 0.0748
# step 72 done in 1.4 secs, train cost = 0.0726
# step 73 done in 1.3 secs, train cost = 0.0704
# step 74 done in 1.3 secs, train cost = 0.0684
# step 75 done in 1.4 secs, train cost = 0.0664
# step 76 done in 1.3 secs, train cost = 0.0645
# step 77 done in 1.3 secs, train cost = 0.0626
# step 78 done in 1.4 secs, train cost = 0.0608
# step 79 done in 1.4 secs, train cost = 0.0591
# step 80 done in 1.3 secs, train cost = 0.0575
# step 81 done in 1.4 secs, train cost = 0.0559
# step 82 done in 1.3 secs, train cost = 0.0543
# step 83 done in 1.1 secs, train cost = 0.0529
# step 84 done in 1.2 secs, train cost = 0.0514
# step 85 done in 1.3 secs, train cost = 0.05
# step 86 done in 1.3 secs, train cost = 0.0487
# step 87 done in 1.3 secs, train cost = 0.0474
# step 88 done in 1.4 secs, train cost = 0.0462
# step 89 done in 1.3 secs, train cost = 0.045
# step 90 done in 1.3 secs, train cost = 0.0438
# step 91 done in 1.4 secs, train cost = 0.0427
# step 92 done in 1.3 secs, train cost = 0.0416
# step 93 done in 1.3 secs, train cost = 0.0406
# step 94 done in 1.4 secs, train cost = 0.0396
# step 95 done in 1.3 secs, train cost = 0.0386
# step 96 done in 1.4 secs, train cost = 0.0377
# step 97 done in 1.3 secs, train cost = 0.0368
# step 98 done in 1.3 secs, train cost = 0.0359
# step 99 done in 1.3 secs, train cost = 0.035
# step 100 done in 1.3 secs, train cost = 0.0342
# step 101 done in 1.3 secs, train cost = 0.0334
# step 102 done in 1.3 secs, train cost = 0.0326
# step 103 done in 1.3 secs, train cost = 0.0319
# step 104 done in 1.3 secs, train cost = 0.0312
# step 105 done in 1.3 secs, train cost = 0.0304
# step 106 done in 1.3 secs, train cost = 0.0298
# step 107 done in 1.3 secs, train cost = 0.0291
# step 108 done in 1.3 secs, train cost = 0.0285
# step 109 done in 1.3 secs, train cost = 0.0278
# step 110 done in 1.3 secs, train cost = 0.0272
# step 111 done in 1.3 secs, train cost = 0.0267
# step 112 done in 1.3 secs, train cost = 0.0261
# step 113 done in 1.3 secs, train cost = 0.0255
# step 114 done in 1.3 secs, train cost = 0.025
# step 115 done in 1.3 secs, train cost = 0.0245
# step 116 done in 1.3 secs, train cost = 0.024
# step 117 done in 1.3 secs, train cost = 0.0235
# step 118 done in 1.3 secs, train cost = 0.023
# step 119 done in 1.3 secs, train cost = 0.0226
# step 120 done in 1.3 secs, train cost = 0.0221
# step 121 done in 1.3 secs, train cost = 0.0217
# step 122 done in 1.4 secs, train cost = 0.0213
# step 123 done in 1.3 secs, train cost = 0.0208
# step 124 done in 1.3 secs, train cost = 0.0204
# step 125 done in 1.3 secs, train cost = 0.0201
# step 126 done in 1.3 secs, train cost = 0.0197
# step 127 done in 1.3 secs, train cost = 0.0193
# step 128 done in 1.3 secs, train cost = 0.019
# step 129 done in 1.3 secs, train cost = 0.0186
# step 130 done in 1.3 secs, train cost = 0.0183
# step 131 done in 1.3 secs, train cost = 0.0179
# step 132 done in 1.3 secs, train cost = 0.0176
# step 133 done in 1.3 secs, train cost = 0.0173
# step 134 done in 1.3 secs, train cost = 0.017
# step 135 done in 1.3 secs, train cost = 0.0167
# step 136 done in 1.2 secs, train cost = 0.0164
# step 137 done in 1.3 secs, train cost = 0.0161
# step 138 done in 1.3 secs, train cost = 0.0159
# step 139 done in 1.3 secs, train cost = 0.0156
# step 140 done in 1.3 secs, train cost = 0.0154
# step 141 done in 1.3 secs, train cost = 0.0151
# step 142 done in 1.3 secs, train cost = 0.0149
# step 143 done in 1.3 secs, train cost = 0.0146
# step 144 done in 1.3 secs, train cost = 0.0144
# step 145 done in 1.4 secs, train cost = 0.0142
# step 146 done in 1.3 secs, train cost = 0.0139
# step 147 done in 1.3 secs, train cost = 0.0137
# step 148 done in 1.3 secs, train cost = 0.0135
# step 149 done in 1.4 secs, train cost = 0.0133
# step 150 done in 1.4 secs, train cost = 0.0131
# step 151 done in 1.3 secs, train cost = 0.0129
# step 152 done in 1.3 secs, train cost = 0.0127
# step 153 done in 1.3 secs, train cost = 0.0125
# step 154 done in 1.3 secs, train cost = 0.0124
# step 155 done in 1.3 secs, train cost = 0.0122
# step 156 done in 1.3 secs, train cost = 0.012
# step 157 done in 1.3 secs, train cost = 0.0118
# step 158 done in 1.4 secs, train cost = 0.0117
# step 159 done in 1.3 secs, train cost = 0.0115
# step 160 done in 1.4 secs, train cost = 0.0114
# step 161 done in 1.3 secs, train cost = 0.0112
# step 162 done in 1.4 secs, train cost = 0.0111
# step 163 done in 1.4 secs, train cost = 0.0109
# step 164 done in 1.3 secs, train cost = 0.0108
# step 165 done in 1.3 secs, train cost = 0.0106
# step 166 done in 1.3 secs, train cost = 0.0105
# step 167 done in 1.3 secs, train cost = 0.0104
# step 168 done in 1.3 secs, train cost = 0.0102
# step 169 done in 1.3 secs, train cost = 0.0101
# step 170 done in 1.2 secs, train cost = 0.01
# step 171 done in 1.2 secs, train cost = 0.0099
# step 172 done in 1.3 secs, train cost = 0.0098
# step 173 done in 1.3 secs, train cost = 0.0096
# step 174 done in 1.3 secs, train cost = 0.0095
# step 175 done in 1.3 secs, train cost = 0.0094
# step 176 done in 1.3 secs, train cost = 0.0093
# step 177 done in 1.3 secs, train cost = 0.0092
# step 178 done in 1.3 secs, train cost = 0.0091
# step 179 done in 1.3 secs, train cost = 0.009
# step 180 done in 1.3 secs, train cost = 0.0089
# step 181 done in 1.3 secs, train cost = 0.0088
# step 182 done in 1.3 secs, train cost = 0.0087
# step 183 done in 1.3 secs, train cost = 0.0086
# step 184 done in 1.3 secs, train cost = 0.0085
# step 185 done in 1.3 secs, train cost = 0.0085
# step 186 done in 1.3 secs, train cost = 0.0084
# step 187 done in 1.3 secs, train cost = 0.0083
# step 188 done in 1.3 secs, train cost = 0.0082
# step 189 done in 1.3 secs, train cost = 0.0081
# step 190 done in 1.2 secs, train cost = 0.0081
# step 191 done in 1.3 secs, train cost = 0.008
# step 192 done in 1.3 secs, train cost = 0.0079
# step 193 done in 1.5 secs, train cost = 0.0078
# step 194 done in 1.4 secs, train cost = 0.0078
# step 195 done in 1.4 secs, train cost = 0.0077
# step 196 done in 1.3 secs, train cost = 0.0076
# step 197 done in 1.3 secs, train cost = 0.0076
# step 198 done in 1.3 secs, train cost = 0.0075
# step 199 done in 1.3 secs, train cost = 0.0074
# step 200 done in 1.3 secs, train cost = 0.0074
# step 201 done in 1.3 secs, train cost = 0.0073
# finished all 200 steps
# [[0.04738977]
#  [0.93622524]
#  [0.19261502]
#  [0.02357337]
#  [0.92728438]
#  [0.06336561]]

# %%
# use optimal weights to simulate system
# [0.04738977, 0.93622524, 0.19261502, 0.02357337, 0.92728438, 0.06336561], cost of 0.0073
opt_weights = w_hist[-1]

T = states.shape[1]
system_model = np.zeros(states.shape)

for ii in range(1,T-1):
    system_model[0,ii+1] = opt_weights[0] + opt_weights[1]*system_model[0,ii] + opt_weights[2]*actions[0,ii]
    system_model[1,ii+1] = opt_weights[3] + opt_weights[4]*system_model[1,ii] + opt_weights[5]*system_model[0,ii]
    
# plot results
plotter.plot_3fer(actions,system_model[0],system_model[1],plot_type = 'continuous')
# Out:
# <img src="data:image/png;base64,..." width="1000">
