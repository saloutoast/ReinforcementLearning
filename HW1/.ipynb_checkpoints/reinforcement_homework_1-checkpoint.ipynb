# %% [markdown]
# # Reinforcement learning from scratch: homework 1

# %% [markdown]
# ### General instructions
#
# Complete the exericse listed below in this Jupyter notebook - leaving all of your code in Python cells in the notebook itself.  Feel free to add any necessary cells.

# %% [markdown]
# ### When submitting this homework:
#
# **Make sure you have put your name at the top of each file**
#
# **Make sure all output is present in your notebook prior to submission**

# %%
# import custom libraries
from custom_library import basic_optimizers as optimizers
from custom_library import variable_order_plotters as plotter

# import autograd functionality
import autograd.numpy as np

# import path to datasets
datapath = 'datasets/'

# this is needed to compensate for %matplotl+ib notebook's tendancy to blow up images when plotted inline
from matplotlib import rcParams
rcParams['figure.autolayout'] = True
# %matplotlib notebook

# autoreload function - so if anything behind the scenes is changeed those changes
# are reflected in the notebook without having to restart the kernel
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 1: </span>  Perform system identification on a small chunk of cruise control data

# %% [markdown]
# In this exercise you will create a system model - denoted as $f_{\text{system}}$ in the [course notes](https://www.dropbox.com/s/m6456ze0fd8kaf8/system_identification_pid_notes.pdf?dl=0) - using a small snippet of cruise control data shown below.  Here our `output sequence` are states $\left\{s_t\right\}_{t=1}^T$, and the `input sequence` corresponding actions $\left\{a_t\right\}_{t=1}^{T-1}$ (we can ignore any finanl action $a_T$ since there is no next state $s_{t+1}$ to regress it on in learning our system model).  Notice at each update step the action is clipped to lie in the range $[-50,100]$ - which is the angle of the pedal against the floor of the car.  Here a negative angle indicates that 'regenerative braking' was applied.

# %%
# load in cruise control data
data = np.loadtxt(datapath + 'cruise_control_data.csv',delimiter = ',')

# extract actions and states 
actions = data[0,1:][np.newaxis,:] # our T-1 actions
states = data[1,:][np.newaxis,:]   # our T states

# plot the test pair
plotter.plot_pair(actions,states)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Some more particulars: here you need to learn the weights of a basic order $1$ linear system model - which takes the form
#
# \begin{equation}
# s_{t+1} = f_{\text{system}}\left(s_t,a_t; \mathbf{w}_\text{system}\right) = w_0 + w_1s_t + w_2a_t
# \end{equation}
#
# by properly minimizing the associated Least Squares cost function
#
# \begin{equation}
# \frac{1}{T-1}\sum_{t=1}^{T-1}\left(f_{\text{system}}\left(s_t,a_t; \mathbf{w}_\text{system}\right) - s_{t+1}\right)^2
# \end{equation}
#
# over the weights $\mathbf{w}_{\text{system}} = \begin{bmatrix} w_0 \\ w_1 \\ w_2 \end{bmatrix}$ where $T$ is the length of our training action sequence.
#
#
# - Build a `Python` version of the system model and Least Squares cost function and minimize it using a first order method.  Use the entire dataset provided for training (i.e., do not worry about validation error)
#
#
# - A simple full batch gradient descent module has been provided in file file `basic_optimizers.py` in the `custom_library` directory for use with this exercise.
#
#
# - After properly minimizing the Least Squares cost above make a plot like the one shown below - which shows the original state data in black, and the system model approximation in blue.  Your trained model should be able to match the data quite well.

# %% [raw]
# <figure>
# <p>
# <img src= 'images/system_id_1.png' width="150%" height="150%" alt=""/>
# </p>
# </figure>

# %%
### system model

def g(w,a_train,s_train):
    ''' Least squares cost function '''
    
    J = 0
    
    T = s_train.shape[1]
    
    for ii in range(1,T-1):
        J = J + (w[0] + w[1]*s_train[0,ii] + w[2]*a_train[0,ii] - s_train[0,ii+1])**2
    
    J = J/(T-1)
    
    return J    

### minimize the least squares (using entire dataset) using full-batch gradient descent
weights = np.random.rand(3,1)

alpha = 0.0002
max_its = 200
verbose = True


w_hist,train_hist = optimizers.gradient_descent(g,weights,actions,states,alpha,max_its,verbose)
# Out:
# step 2 done in 0.2 secs, train cost = 3.6991
# step 3 done in 0.2 secs, train cost = 1.0618
# step 4 done in 0.2 secs, train cost = 0.3636
# step 5 done in 0.2 secs, train cost = 0.1751
# step 6 done in 0.2 secs, train cost = 0.121
# step 7 done in 0.2 secs, train cost = 0.1027
# step 8 done in 0.2 secs, train cost = 0.0944
# step 9 done in 0.1 secs, train cost = 0.089
# step 10 done in 0.2 secs, train cost = 0.0848
# step 11 done in 0.2 secs, train cost = 0.0813
# step 12 done in 0.3 secs, train cost = 0.0782
# step 13 done in 0.2 secs, train cost = 0.0755
# step 14 done in 0.2 secs, train cost = 0.0731
# step 15 done in 0.2 secs, train cost = 0.071
# step 16 done in 0.2 secs, train cost = 0.0691
# step 17 done in 0.2 secs, train cost = 0.0675
# step 18 done in 0.2 secs, train cost = 0.066
# step 19 done in 0.2 secs, train cost = 0.0648
# step 20 done in 0.2 secs, train cost = 0.0637
# step 21 done in 0.2 secs, train cost = 0.0627
# step 22 done in 0.2 secs, train cost = 0.0618
# step 23 done in 0.2 secs, train cost = 0.061
# step 24 done in 0.2 secs, train cost = 0.0604
# step 25 done in 0.2 secs, train cost = 0.0598
# step 26 done in 0.1 secs, train cost = 0.0592
# step 27 done in 0.2 secs, train cost = 0.0588
# step 28 done in 0.2 secs, train cost = 0.0584
# step 29 done in 0.2 secs, train cost = 0.058
# step 30 done in 0.2 secs, train cost = 0.0577
# step 31 done in 0.2 secs, train cost = 0.0574
# step 32 done in 0.2 secs, train cost = 0.0572
# step 33 done in 0.3 secs, train cost = 0.057
# step 34 done in 0.2 secs, train cost = 0.0568
# step 35 done in 0.1 secs, train cost = 0.0566
# step 36 done in 0.3 secs, train cost = 0.0565
# step 37 done in 0.2 secs, train cost = 0.0563
# step 38 done in 0.2 secs, train cost = 0.0562
# step 39 done in 0.2 secs, train cost = 0.0561
# step 40 done in 0.2 secs, train cost = 0.056
# step 41 done in 0.2 secs, train cost = 0.0559
# step 42 done in 0.2 secs, train cost = 0.0559
# step 43 done in 0.3 secs, train cost = 0.0558
# step 44 done in 0.2 secs, train cost = 0.0558
# step 45 done in 0.2 secs, train cost = 0.0557
# step 46 done in 0.2 secs, train cost = 0.0557
# step 47 done in 0.2 secs, train cost = 0.0556
# step 48 done in 0.2 secs, train cost = 0.0556
# step 49 done in 0.3 secs, train cost = 0.0556
# step 50 done in 0.3 secs, train cost = 0.0556
# step 51 done in 0.3 secs, train cost = 0.0555
# step 52 done in 0.3 secs, train cost = 0.0555
# step 53 done in 0.2 secs, train cost = 0.0555
# step 54 done in 0.2 secs, train cost = 0.0555
# step 55 done in 0.2 secs, train cost = 0.0555
# step 56 done in 0.2 secs, train cost = 0.0555
# step 57 done in 0.2 secs, train cost = 0.0554
# step 58 done in 0.2 secs, train cost = 0.0554
# step 59 done in 0.2 secs, train cost = 0.0554
# step 60 done in 0.2 secs, train cost = 0.0554
# step 61 done in 0.2 secs, train cost = 0.0554
# step 62 done in 0.2 secs, train cost = 0.0554
# step 63 done in 0.3 secs, train cost = 0.0554
# step 64 done in 0.2 secs, train cost = 0.0554
# step 65 done in 0.2 secs, train cost = 0.0554
# step 66 done in 0.2 secs, train cost = 0.0554
# step 67 done in 0.2 secs, train cost = 0.0554
# step 68 done in 0.2 secs, train cost = 0.0554
# step 69 done in 0.3 secs, train cost = 0.0554
# step 70 done in 0.3 secs, train cost = 0.0554
# step 71 done in 0.1 secs, train cost = 0.0554
# step 72 done in 0.2 secs, train cost = 0.0554
# step 73 done in 0.2 secs, train cost = 0.0554
# step 74 done in 0.2 secs, train cost = 0.0554
# step 75 done in 0.2 secs, train cost = 0.0554
# step 76 done in 0.2 secs, train cost = 0.0554
# step 77 done in 0.2 secs, train cost = 0.0554
# step 78 done in 0.2 secs, train cost = 0.0554
# step 79 done in 0.3 secs, train cost = 0.0554
# step 80 done in 0.2 secs, train cost = 0.0554
# step 81 done in 0.2 secs, train cost = 0.0554
# step 82 done in 0.3 secs, train cost = 0.0554
# step 83 done in 0.3 secs, train cost = 0.0554
# step 84 done in 0.3 secs, train cost = 0.0554
# step 85 done in 0.3 secs, train cost = 0.0554
# step 86 done in 0.3 secs, train cost = 0.0554
# step 87 done in 0.3 secs, train cost = 0.0554
# step 88 done in 0.2 secs, train cost = 0.0554
# step 89 done in 0.2 secs, train cost = 0.0554
# step 90 done in 0.2 secs, train cost = 0.0554
# step 91 done in 0.2 secs, train cost = 0.0554
# step 92 done in 0.2 secs, train cost = 0.0554
# step 93 done in 0.2 secs, train cost = 0.0554
# step 94 done in 0.2 secs, train cost = 0.0554
# step 95 done in 0.2 secs, train cost = 0.0554
# step 96 done in 0.2 secs, train cost = 0.0554
# step 97 done in 0.2 secs, train cost = 0.0554
# step 98 done in 0.2 secs, train cost = 0.0554
# step 99 done in 0.2 secs, train cost = 0.0554
# step 100 done in 0.2 secs, train cost = 0.0554
# step 101 done in 0.2 secs, train cost = 0.0554
# step 102 done in 0.2 secs, train cost = 0.0554
# step 103 done in 0.2 secs, train cost = 0.0554
# step 104 done in 0.2 secs, train cost = 0.0554
# step 105 done in 0.2 secs, train cost = 0.0554
# step 106 done in 0.2 secs, train cost = 0.0554
# step 107 done in 0.2 secs, train cost = 0.0554
# step 108 done in 0.2 secs, train cost = 0.0554
# step 109 done in 0.2 secs, train cost = 0.0554
# step 110 done in 0.2 secs, train cost = 0.0554
# step 111 done in 0.2 secs, train cost = 0.0554
# step 112 done in 0.2 secs, train cost = 0.0554
# step 113 done in 0.2 secs, train cost = 0.0554
# step 114 done in 0.2 secs, train cost = 0.0554
# step 115 done in 0.3 secs, train cost = 0.0554
# step 116 done in 0.2 secs, train cost = 0.0554
# step 117 done in 0.2 secs, train cost = 0.0554
# step 118 done in 0.2 secs, train cost = 0.0554
# step 119 done in 0.2 secs, train cost = 0.0554
# step 120 done in 0.2 secs, train cost = 0.0554
# step 121 done in 0.2 secs, train cost = 0.0554
# step 122 done in 0.2 secs, train cost = 0.0554
# step 123 done in 0.2 secs, train cost = 0.0554
# step 124 done in 0.2 secs, train cost = 0.0554
# step 125 done in 0.1 secs, train cost = 0.0554
# step 126 done in 0.2 secs, train cost = 0.0554
# step 127 done in 0.2 secs, train cost = 0.0554
# step 128 done in 0.2 secs, train cost = 0.0554
# step 129 done in 0.2 secs, train cost = 0.0554
# step 130 done in 0.2 secs, train cost = 0.0554
# step 131 done in 0.2 secs, train cost = 0.0554
# step 132 done in 0.2 secs, train cost = 0.0554
# step 133 done in 0.2 secs, train cost = 0.0554
# step 134 done in 0.2 secs, train cost = 0.0554
# step 135 done in 0.2 secs, train cost = 0.0554
# step 136 done in 0.2 secs, train cost = 0.0554
# step 137 done in 0.2 secs, train cost = 0.0554
# step 138 done in 0.2 secs, train cost = 0.0554
# step 139 done in 0.2 secs, train cost = 0.0554
# step 140 done in 0.2 secs, train cost = 0.0554
# step 141 done in 0.2 secs, train cost = 0.0554
# step 142 done in 0.2 secs, train cost = 0.0554
# step 143 done in 0.2 secs, train cost = 0.0554
# step 144 done in 0.2 secs, train cost = 0.0554
# step 145 done in 0.2 secs, train cost = 0.0554
# step 146 done in 0.2 secs, train cost = 0.0554
# step 147 done in 0.2 secs, train cost = 0.0554
# step 148 done in 0.2 secs, train cost = 0.0554
# step 149 done in 0.2 secs, train cost = 0.0554
# step 150 done in 0.2 secs, train cost = 0.0554
# step 151 done in 0.2 secs, train cost = 0.0554
# step 152 done in 0.2 secs, train cost = 0.0554
# step 153 done in 0.2 secs, train cost = 0.0554
# step 154 done in 0.2 secs, train cost = 0.0554
# step 155 done in 0.2 secs, train cost = 0.0554
# step 156 done in 0.2 secs, train cost = 0.0554
# step 157 done in 0.2 secs, train cost = 0.0554
# step 158 done in 0.2 secs, train cost = 0.0554
# step 159 done in 0.2 secs, train cost = 0.0554
# step 160 done in 0.2 secs, train cost = 0.0554
# step 161 done in 0.2 secs, train cost = 0.0554
# step 162 done in 0.2 secs, train cost = 0.0554
# step 163 done in 0.2 secs, train cost = 0.0554
# step 164 done in 0.2 secs, train cost = 0.0554
# step 165 done in 0.2 secs, train cost = 0.0554
# step 166 done in 0.2 secs, train cost = 0.0554
# step 167 done in 0.2 secs, train cost = 0.0554
# step 168 done in 0.2 secs, train cost = 0.0554
# step 169 done in 0.1 secs, train cost = 0.0554
# step 170 done in 0.2 secs, train cost = 0.0554
# step 171 done in 0.2 secs, train cost = 0.0554
# step 172 done in 0.2 secs, train cost = 0.0554
# step 173 done in 0.2 secs, train cost = 0.0554
# step 174 done in 0.2 secs, train cost = 0.0554
# step 175 done in 0.2 secs, train cost = 0.0554
# step 176 done in 0.2 secs, train cost = 0.0554
# step 177 done in 0.2 secs, train cost = 0.0554
# step 178 done in 0.2 secs, train cost = 0.0554
# step 179 done in 0.2 secs, train cost = 0.0554
# step 180 done in 0.2 secs, train cost = 0.0554
# step 181 done in 0.2 secs, train cost = 0.0554
# step 182 done in 0.2 secs, train cost = 0.0554
# step 183 done in 0.2 secs, train cost = 0.0554
# step 184 done in 0.2 secs, train cost = 0.0554
# step 185 done in 0.2 secs, train cost = 0.0554
# step 186 done in 0.1 secs, train cost = 0.0554
# step 187 done in 0.2 secs, train cost = 0.0554
# step 188 done in 0.2 secs, train cost = 0.0554
# step 189 done in 0.2 secs, train cost = 0.0554
# step 190 done in 0.2 secs, train cost = 0.0554
# step 191 done in 0.2 secs, train cost = 0.0554
# step 192 done in 0.2 secs, train cost = 0.0554
# step 193 done in 0.2 secs, train cost = 0.0554
# step 194 done in 0.2 secs, train cost = 0.0554
# step 195 done in 0.2 secs, train cost = 0.0554
# step 196 done in 0.2 secs, train cost = 0.0554
# step 197 done in 0.2 secs, train cost = 0.0554
# step 198 done in 0.2 secs, train cost = 0.0554
# step 199 done in 0.2 secs, train cost = 0.0554
# step 200 done in 0.2 secs, train cost = 0.0554
# step 201 done in 0.2 secs, train cost = 0.0554
# finished all 200 steps

# %%
### plot original state data and system model approximation

# evaluate output of learned model
opt_weights = w_hist[-1]
system_model = opt_weights[0] + opt_weights[1]*states[0,0:-1] + opt_weights[2]*actions

# initialize figure
fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(111); 

# plot data
ax1.plot(np.arange(np.size(system_model)),system_model.flatten(),c = 'cyan',linewidth = 2.5,label = 'System Model',zorder = 2)
ax1.plot(np.arange(np.size(states)),states.flatten(),c = 'black',linewidth = 2,label = 'Original States',zorder = 1)

# label axes and title
ax1.set_title('Output Sequences')
ax1.set_xlabel('Step')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 2: </span>  Train an unregularized PID controller for the cruise control problem

# %% [markdown]
# In this exercise you will tune the parameters of a PID controller automatically so that the system model trained in the previous exercise matches the example set point sequence shown below.  Note: you need to have finished the previous exercise in order to properly solve this one!

# %%
csvname,delimiter = ',')[np.newaxis,:]

# plot set point sequence
plotter.plot_setpoints(set_points)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Implement a `Pythonic` version of the PID controller Least Squares cost function discussed in the [course notes](https://www.dropbox.com/s/m6456ze0fd8kaf8/system_identification_pid_notes.pdf?dl=0).  You should be able to learn an action / state sequence pair so that your system model responds fairly well to the input set point sequence.  The image below shows the results of an action/state sequence pair learned by a fully tuned PID controller.  The top panel shows the set point sequence in dashed black, with the state sequence defined by the controller in blue.  The bottom panel shows the corresponding action sequence defined by the controller.
#
# A few notes:
# - For this exercise you need not worry about regularizing either the state or action sequences when training the controller - simply tune it as best as you can.
#
#
# - Even though a PID controller is technically a Recurrent Network (which can be slow to train), here we only deal with a fairly small dataset of set points and there only 4 parameters to tune - so you can apply the simplest kind of first order algorithm to properly minimize the controller cost (e.g., a full batch gradient descent optimizer).

# %% [markdown]
# <figure>
# <p>
# <img src= 'images/PID_1.png' width="150%" height="150%" alt=""/>
# </p>
# </figure>

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 3: </span>  System identification on the two-tank problem

# %% [markdown]
# In this exercise you will create a system model - using a small snippet of cruise control data shown below.  This comes from a real life two-tanks experiment as shown on page 4 of the [course notes](https://www.dropbox.com/s/m6456ze0fd8kaf8/system_identification_pid_notes.pdf?dl=0).  The amount of water allowed into the top tank (per second) - the action sequence $a_t$ - is shown as the black curve in the bottom panel.  In the top panel the *upper* tank water level $s_{1,t}$ is shown in green, and the bottom tank level $s_{2,t}$ is shown in magenta.

# %%
# This code cell will not be shown in the HTML version of this notebook
# load series
data = np.loadtxt(datapath + 'cascaded_tanks_1.csv',delimiter = ',')
actions = data[0:1,1:]
states = data[1:,:]

# plot the test pair
plotter.plot_3fer(actions,states[0],states[1],plot_type = 'continuous')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# This system has two $s_{1,t}$ and $s_{2,t}$, hence the system model consists of an equation for each.  The upper tank level $s_{1,t}$ is dependent on its own history and - of course- the amount of water $a_t$ that is poured into it.  A simple linear system model for it then looks like
#
# \begin{equation}
# s_{1,t+1} = w_0 + w_1 s_{1,t} + w_2 a_t.
# \end{equation}
#
# Since we know that the upper tank drains into the lower one, the simplest sort of system model we can make for the lower tank level $s_{2,t}$ is that it is proportional to its prior value and that of the upper tank, as
#
# \begin{equation}
# s_{2,t+1} = w_3 + w_4s_{2,t} + w_5 s_{1,t}.
# \end{equation}
#
# Together - using the simplest model for this system we could think of - we have the following two system model equations
#
# \begin{array}
# \
# s_{1,t+1} = w_0 + w_1 s_{1,t} + w_2 a_t \\
# s_{2,t+1} = w_3 + w_4s_{2,t} + w_5 s_{1,t}.
# \end{array}

# %% [markdown]
# Tune the parameters of this system model $w_0$ through $w_5$ via minimizing a Least Squares cost function, using the data shown above for training (i.e., you need not cut off a chunk of it for validation - use it all for training).  Make sure to plot the fit your model provides on the training data.  You can see this exact system model fit to this exact dataset in the course notes - make sure your fit looks fairly similar.
