# %% [markdown]
# # Reinforcement learning from scratch: homework 1

# %% [markdown]
# ### General instructions
#
# Complete the exericse listed below in this Jupyter notebook - leaving all of your code in Python cells in the notebook itself.  Feel free to add any necessary cells.

# %% [markdown]
# ### When submitting this homework:
#
# **Make sure you have put your name at the top of each file**
#
# **Make sure all output is present in your notebook prior to submission**

# %%
# import custom libraries
from custom_library import basic_optimizers as optimizers
from custom_library import variable_order_plotters as plotter

# import autograd functionality
import autograd.numpy as np

# import path to datasets
datapath = 'datasets/'

# this is needed to compensate for %matplotl+ib notebook's tendancy to blow up images when plotted inline
from matplotlib import rcParams
rcParams['figure.autolayout'] = True
# %matplotlib notebook

# autoreload function - so if anything behind the scenes is changeed those changes
# are reflected in the notebook without having to restart the kernel
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 1: </span>  Perform system identification on a small chunk of cruise control data

# %% [markdown]
# In this exercise you will create a system model - denoted as $f_{\text{system}}$ in the [course notes](https://www.dropbox.com/s/m6456ze0fd8kaf8/system_identification_pid_notes.pdf?dl=0) - using a small snippet of cruise control data shown below.  Here our `output sequence` are states $\left\{s_t\right\}_{t=1}^T$, and the `input sequence` corresponding actions $\left\{a_t\right\}_{t=1}^{T-1}$ (we can ignore any finanl action $a_T$ since there is no next state $s_{t+1}$ to regress it on in learning our system model).  Notice at each update step the action is clipped to lie in the range $[-50,100]$ - which is the angle of the pedal against the floor of the car.  Here a negative angle indicates that 'regenerative braking' was applied.

# %%
# load in cruise control data
data = np.loadtxt(datapath + 'cruise_control_data.csv',delimiter = ',')

# extract actions and states 
actions = data[0,1:][np.newaxis,:] # our T-1 actions
states = data[1,:][np.newaxis,:]   # our T states

# plot the test pair
plotter.plot_pair(actions,states)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Some more particulars: here you need to learn the weights of a basic order $1$ linear system model - which takes the form
#
# \begin{equation}
# s_{t+1} = f_{\text{system}}\left(s_t,a_t; \mathbf{w}_\text{system}\right) = w_0 + w_1s_t + w_2a_t
# \end{equation}
#
# by properly minimizing the associated Least Squares cost function
#
# \begin{equation}
# \frac{1}{T-1}\sum_{t=1}^{T-1}\left(f_{\text{system}}\left(s_t,a_t; \mathbf{w}_\text{system}\right) - s_{t+1}\right)^2
# \end{equation}
#
# over the weights $\mathbf{w}_{\text{system}} = \begin{bmatrix} w_0 \\ w_1 \\ w_2 \end{bmatrix}$ where $T$ is the length of our training action sequence.
#
#
# - Build a `Python` version of the system model and Least Squares cost function and minimize it using a first order method.  Use the entire dataset provided for training (i.e., do not worry about validation error)
#
#
# - A simple full batch gradient descent module has been provided in file file `basic_optimizers.py` in the `custom_library` directory for use with this exercise.
#
#
# - After properly minimizing the Least Squares cost above make a plot like the one shown below - which shows the original state data in black, and the system model approximation in blue.  Your trained model should be able to match the data quite well.

# %% [raw]
# <figure>
# <p>
# <img src= 'images/system_id_1.png' width="150%" height="150%" alt=""/>
# </p>
# </figure>

# %%
### system model

def g(w,a_train,s_train):
    ''' Least squares cost function '''
    
    J = 0
    
    T = s_train.shape[1]
    
    for ii in range(1,T-1):
        J = J + (w[0] + w[1]*s_train[0,ii] + w[2]*a_train[0,ii] - s_train[0,ii+1])**2
    
    J = J/(T-1)
    
    return J    

### minimize the least squares (using entire dataset) using full-batch gradient descent
weights = np.random.rand(3,1)

alpha = 0.00025
max_its = 500 # could make larger for a better fit?
verbose = True


w_hist,train_hist = optimizers.gradient_descent(g,weights,actions,states,alpha,max_its,verbose)
# Out:
# step 2 done in 0.2 secs, train cost = 1099.3091
# step 3 done in 0.2 secs, train cost = 875.3915
# step 4 done in 0.2 secs, train cost = 697.2995
# step 5 done in 0.2 secs, train cost = 555.6226
# step 6 done in 0.2 secs, train cost = 442.8878
# step 7 done in 0.2 secs, train cost = 353.1595
# step 8 done in 0.2 secs, train cost = 281.7231
# step 9 done in 0.2 secs, train cost = 224.8328
# step 10 done in 0.2 secs, train cost = 179.5127
# step 11 done in 0.2 secs, train cost = 143.3975
# step 12 done in 0.2 secs, train cost = 114.6075
# step 13 done in 0.2 secs, train cost = 91.6483
# step 14 done in 0.2 secs, train cost = 73.3316
# step 15 done in 0.2 secs, train cost = 58.7125
# step 16 done in 0.2 secs, train cost = 47.0392
# step 17 done in 0.3 secs, train cost = 37.7138
# step 18 done in 0.3 secs, train cost = 30.2601
# step 19 done in 0.2 secs, train cost = 24.2994
# step 20 done in 0.2 secs, train cost = 19.5299
# step 21 done in 0.2 secs, train cost = 15.7112
# step 22 done in 0.2 secs, train cost = 12.6519
# step 23 done in 0.2 secs, train cost = 10.1993
# step 24 done in 0.2 secs, train cost = 8.2317
# step 25 done in 0.2 secs, train cost = 6.6521
# step 26 done in 0.2 secs, train cost = 5.383
# step 27 done in 0.2 secs, train cost = 4.3625
# step 28 done in 0.2 secs, train cost = 3.5412
# step 29 done in 0.2 secs, train cost = 2.8797
# step 30 done in 0.2 secs, train cost = 2.3464
# step 31 done in 0.2 secs, train cost = 1.916
# step 32 done in 0.2 secs, train cost = 1.5684
# step 33 done in 0.2 secs, train cost = 1.2872
# step 34 done in 0.3 secs, train cost = 1.0597
# step 35 done in 0.2 secs, train cost = 0.8753
# step 36 done in 0.2 secs, train cost = 0.7257
# step 37 done in 0.2 secs, train cost = 0.6042
# step 38 done in 0.3 secs, train cost = 0.5054
# step 39 done in 0.2 secs, train cost = 0.4249
# step 40 done in 0.2 secs, train cost = 0.3594
# step 41 done in 0.2 secs, train cost = 0.3059
# step 42 done in 0.2 secs, train cost = 0.2621
# step 43 done in 0.2 secs, train cost = 0.2263
# step 44 done in 0.2 secs, train cost = 0.197
# step 45 done in 0.2 secs, train cost = 0.173
# step 46 done in 0.2 secs, train cost = 0.1532
# step 47 done in 0.2 secs, train cost = 0.1369
# step 48 done in 0.2 secs, train cost = 0.1236
# step 49 done in 0.2 secs, train cost = 0.1125
# step 50 done in 0.2 secs, train cost = 0.1034
# step 51 done in 0.3 secs, train cost = 0.0959
# step 52 done in 0.2 secs, train cost = 0.0896
# step 53 done in 0.2 secs, train cost = 0.0844
# step 54 done in 0.2 secs, train cost = 0.0801
# step 55 done in 0.2 secs, train cost = 0.0766
# step 56 done in 0.2 secs, train cost = 0.0736
# step 57 done in 0.2 secs, train cost = 0.0711
# step 58 done in 0.2 secs, train cost = 0.0691
# step 59 done in 0.2 secs, train cost = 0.0673
# step 60 done in 0.2 secs, train cost = 0.0659
# step 61 done in 0.3 secs, train cost = 0.0647
# step 62 done in 0.2 secs, train cost = 0.0637
# step 63 done in 0.2 secs, train cost = 0.0628
# step 64 done in 0.2 secs, train cost = 0.0621
# step 65 done in 0.2 secs, train cost = 0.0615
# step 66 done in 0.3 secs, train cost = 0.061
# step 67 done in 0.2 secs, train cost = 0.0606
# step 68 done in 0.2 secs, train cost = 0.0603
# step 69 done in 0.2 secs, train cost = 0.06
# step 70 done in 0.2 secs, train cost = 0.0597
# step 71 done in 0.2 secs, train cost = 0.0595
# step 72 done in 0.2 secs, train cost = 0.0593
# step 73 done in 0.2 secs, train cost = 0.0592
# step 74 done in 0.3 secs, train cost = 0.059
# step 75 done in 0.3 secs, train cost = 0.0589
# step 76 done in 0.1 secs, train cost = 0.0588
# step 77 done in 0.2 secs, train cost = 0.0588
# step 78 done in 0.2 secs, train cost = 0.0587
# step 79 done in 0.2 secs, train cost = 0.0586
# step 80 done in 0.2 secs, train cost = 0.0586
# step 81 done in 0.3 secs, train cost = 0.0585
# step 82 done in 0.3 secs, train cost = 0.0585
# step 83 done in 0.3 secs, train cost = 0.0585
# step 84 done in 0.2 secs, train cost = 0.0585
# step 85 done in 0.2 secs, train cost = 0.0584
# step 86 done in 0.1 secs, train cost = 0.0584
# step 87 done in 0.2 secs, train cost = 0.0584
# step 88 done in 0.2 secs, train cost = 0.0584
# step 89 done in 0.2 secs, train cost = 0.0584
# step 90 done in 0.2 secs, train cost = 0.0584
# step 91 done in 0.3 secs, train cost = 0.0584
# step 92 done in 0.3 secs, train cost = 0.0584
# step 93 done in 0.2 secs, train cost = 0.0584
# step 94 done in 0.2 secs, train cost = 0.0583
# step 95 done in 0.2 secs, train cost = 0.0583
# step 96 done in 0.3 secs, train cost = 0.0583
# step 97 done in 0.4 secs, train cost = 0.0583
# step 98 done in 0.5 secs, train cost = 0.0583
# step 99 done in 0.3 secs, train cost = 0.0583
# step 100 done in 0.3 secs, train cost = 0.0583
# step 101 done in 0.3 secs, train cost = 0.0583
# step 102 done in 0.4 secs, train cost = 0.0583
# step 103 done in 0.4 secs, train cost = 0.0583
# step 104 done in 0.2 secs, train cost = 0.0583
# step 105 done in 0.2 secs, train cost = 0.0583
# step 106 done in 0.3 secs, train cost = 0.0583
# step 107 done in 0.3 secs, train cost = 0.0583
# step 108 done in 0.4 secs, train cost = 0.0583
# step 109 done in 0.2 secs, train cost = 0.0583
# step 110 done in 0.2 secs, train cost = 0.0583
# step 111 done in 0.2 secs, train cost = 0.0583
# step 112 done in 0.2 secs, train cost = 0.0583
# step 113 done in 0.1 secs, train cost = 0.0583
# step 114 done in 0.2 secs, train cost = 0.0583
# step 115 done in 0.2 secs, train cost = 0.0583
# step 116 done in 0.2 secs, train cost = 0.0583
# step 117 done in 0.4 secs, train cost = 0.0583
# step 118 done in 0.3 secs, train cost = 0.0583
# step 119 done in 0.2 secs, train cost = 0.0583
# step 120 done in 0.2 secs, train cost = 0.0583
# step 121 done in 0.1 secs, train cost = 0.0583
# step 122 done in 0.2 secs, train cost = 0.0583
# step 123 done in 0.2 secs, train cost = 0.0583
# step 124 done in 0.2 secs, train cost = 0.0583
# step 125 done in 0.2 secs, train cost = 0.0583
# step 126 done in 0.2 secs, train cost = 0.0583
# step 127 done in 0.2 secs, train cost = 0.0583
# step 128 done in 0.2 secs, train cost = 0.0583
# step 129 done in 0.2 secs, train cost = 0.0583
# step 130 done in 0.1 secs, train cost = 0.0583
# step 131 done in 0.2 secs, train cost = 0.0583
# step 132 done in 0.2 secs, train cost = 0.0583
# step 133 done in 0.2 secs, train cost = 0.0583
# step 134 done in 0.2 secs, train cost = 0.0583
# step 135 done in 0.2 secs, train cost = 0.0583
# step 136 done in 0.2 secs, train cost = 0.0583
# step 137 done in 0.2 secs, train cost = 0.0583
# step 138 done in 0.2 secs, train cost = 0.0583
# step 139 done in 0.2 secs, train cost = 0.0583
# step 140 done in 0.2 secs, train cost = 0.0583
# step 141 done in 0.2 secs, train cost = 0.0583
# step 142 done in 0.2 secs, train cost = 0.0583
# step 143 done in 0.2 secs, train cost = 0.0583
# step 144 done in 0.2 secs, train cost = 0.0583
# step 145 done in 0.2 secs, train cost = 0.0583
# step 146 done in 0.2 secs, train cost = 0.0583
# step 147 done in 0.2 secs, train cost = 0.0583
# step 148 done in 0.1 secs, train cost = 0.0583
# step 149 done in 0.2 secs, train cost = 0.0583
# step 150 done in 0.2 secs, train cost = 0.0583
# step 151 done in 0.2 secs, train cost = 0.0583
# step 152 done in 0.2 secs, train cost = 0.0583
# step 153 done in 0.2 secs, train cost = 0.0583
# step 154 done in 0.2 secs, train cost = 0.0583
# step 155 done in 0.2 secs, train cost = 0.0583
# step 156 done in 0.2 secs, train cost = 0.0583
# step 157 done in 0.4 secs, train cost = 0.0583
# step 158 done in 0.2 secs, train cost = 0.0583
# step 159 done in 0.2 secs, train cost = 0.0583
# step 160 done in 0.2 secs, train cost = 0.0583
# step 161 done in 0.2 secs, train cost = 0.0583
# step 162 done in 0.2 secs, train cost = 0.0583
# step 163 done in 0.3 secs, train cost = 0.0583
# step 164 done in 0.4 secs, train cost = 0.0583
# step 165 done in 0.2 secs, train cost = 0.0583
# step 166 done in 0.2 secs, train cost = 0.0583
# step 167 done in 0.3 secs, train cost = 0.0583
# step 168 done in 0.4 secs, train cost = 0.0583
# step 169 done in 0.3 secs, train cost = 0.0583
# step 170 done in 0.3 secs, train cost = 0.0583
# step 171 done in 0.5 secs, train cost = 0.0583
# step 172 done in 0.3 secs, train cost = 0.0583
# step 173 done in 0.2 secs, train cost = 0.0583
# step 174 done in 0.3 secs, train cost = 0.0583
# step 175 done in 0.2 secs, train cost = 0.0583
# step 176 done in 0.2 secs, train cost = 0.0583
# step 177 done in 0.2 secs, train cost = 0.0583
# step 178 done in 0.2 secs, train cost = 0.0583
# step 179 done in 0.2 secs, train cost = 0.0583
# step 180 done in 0.2 secs, train cost = 0.0583
# step 181 done in 0.2 secs, train cost = 0.0583
# step 182 done in 0.2 secs, train cost = 0.0583
# step 183 done in 0.2 secs, train cost = 0.0583
# step 184 done in 0.1 secs, train cost = 0.0583
# step 185 done in 0.2 secs, train cost = 0.0583
# step 186 done in 0.3 secs, train cost = 0.0583
# step 187 done in 0.3 secs, train cost = 0.0583
# step 188 done in 0.3 secs, train cost = 0.0583
# step 189 done in 0.4 secs, train cost = 0.0583
# step 190 done in 0.3 secs, train cost = 0.0583
# step 191 done in 0.3 secs, train cost = 0.0583
# step 192 done in 0.3 secs, train cost = 0.0583
# step 193 done in 0.3 secs, train cost = 0.0583
# step 194 done in 0.3 secs, train cost = 0.0583
# step 195 done in 0.4 secs, train cost = 0.0583
# step 196 done in 0.4 secs, train cost = 0.0583
# step 197 done in 0.3 secs, train cost = 0.0583
# step 198 done in 0.4 secs, train cost = 0.0583
# step 199 done in 0.4 secs, train cost = 0.0583
# step 200 done in 0.3 secs, train cost = 0.0583
# step 201 done in 0.4 secs, train cost = 0.0583
# step 202 done in 0.3 secs, train cost = 0.0583
# step 203 done in 0.4 secs, train cost = 0.0583
# step 204 done in 0.3 secs, train cost = 0.0583
# step 205 done in 0.3 secs, train cost = 0.0583
# step 206 done in 0.3 secs, train cost = 0.0583
# step 207 done in 0.2 secs, train cost = 0.0583
# step 208 done in 0.3 secs, train cost = 0.0583
# step 209 done in 0.2 secs, train cost = 0.0583
# step 210 done in 0.2 secs, train cost = 0.0583
# step 211 done in 0.2 secs, train cost = 0.0583
# step 212 done in 0.2 secs, train cost = 0.0583
# step 213 done in 0.2 secs, train cost = 0.0583
# step 214 done in 0.3 secs, train cost = 0.0583
# step 215 done in 0.3 secs, train cost = 0.0583
# step 216 done in 0.2 secs, train cost = 0.0583
# step 217 done in 0.2 secs, train cost = 0.0583
# step 218 done in 0.2 secs, train cost = 0.0583
# step 219 done in 0.2 secs, train cost = 0.0583
# step 220 done in 0.2 secs, train cost = 0.0583
# step 221 done in 0.3 secs, train cost = 0.0583
# step 222 done in 0.3 secs, train cost = 0.0583
# step 223 done in 0.3 secs, train cost = 0.0583
# step 224 done in 0.2 secs, train cost = 0.0583
# step 225 done in 0.2 secs, train cost = 0.0583
# step 226 done in 0.2 secs, train cost = 0.0583
# step 227 done in 0.2 secs, train cost = 0.0583
# step 228 done in 0.2 secs, train cost = 0.0583
# step 229 done in 0.2 secs, train cost = 0.0583
# step 230 done in 0.2 secs, train cost = 0.0583
# step 231 done in 0.2 secs, train cost = 0.0583
# step 232 done in 0.2 secs, train cost = 0.0583
# step 233 done in 0.2 secs, train cost = 0.0582
# step 234 done in 0.2 secs, train cost = 0.0582
# step 235 done in 0.2 secs, train cost = 0.0582
# step 236 done in 0.2 secs, train cost = 0.0582
# step 237 done in 0.1 secs, train cost = 0.0582
# step 238 done in 0.2 secs, train cost = 0.0582
# step 239 done in 0.2 secs, train cost = 0.0582
# step 240 done in 0.2 secs, train cost = 0.0582
# step 241 done in 0.2 secs, train cost = 0.0582
# step 242 done in 0.2 secs, train cost = 0.0582
# step 243 done in 0.2 secs, train cost = 0.0582
# step 244 done in 0.2 secs, train cost = 0.0582
# step 245 done in 0.2 secs, train cost = 0.0582
# step 246 done in 0.2 secs, train cost = 0.0582
# step 247 done in 0.2 secs, train cost = 0.0582
# step 248 done in 0.2 secs, train cost = 0.0582
# step 249 done in 0.2 secs, train cost = 0.0582
# step 250 done in 0.2 secs, train cost = 0.0582
# step 251 done in 0.2 secs, train cost = 0.0582
# step 252 done in 0.2 secs, train cost = 0.0582
# step 253 done in 0.3 secs, train cost = 0.0582
# step 254 done in 0.3 secs, train cost = 0.0582
# step 255 done in 0.2 secs, train cost = 0.0582
# step 256 done in 0.3 secs, train cost = 0.0582
# step 257 done in 0.3 secs, train cost = 0.0582
# step 258 done in 0.3 secs, train cost = 0.0582
# step 259 done in 0.3 secs, train cost = 0.0582
# step 260 done in 0.3 secs, train cost = 0.0582
# step 261 done in 0.3 secs, train cost = 0.0582
# step 262 done in 0.3 secs, train cost = 0.0582
# step 263 done in 0.3 secs, train cost = 0.0582
# step 264 done in 0.1 secs, train cost = 0.0582
# step 265 done in 0.2 secs, train cost = 0.0582
# step 266 done in 0.2 secs, train cost = 0.0582
# step 267 done in 0.2 secs, train cost = 0.0582
# step 268 done in 0.2 secs, train cost = 0.0582
# step 269 done in 0.2 secs, train cost = 0.0582
# step 270 done in 0.3 secs, train cost = 0.0582
# step 271 done in 0.3 secs, train cost = 0.0582
# step 272 done in 0.3 secs, train cost = 0.0582
# step 273 done in 0.2 secs, train cost = 0.0582
# step 274 done in 0.3 secs, train cost = 0.0582
# step 275 done in 0.3 secs, train cost = 0.0582
# step 276 done in 0.3 secs, train cost = 0.0582
# step 277 done in 0.3 secs, train cost = 0.0582
# step 278 done in 0.3 secs, train cost = 0.0582
# step 279 done in 0.2 secs, train cost = 0.0582
# step 280 done in 0.2 secs, train cost = 0.0582
# step 281 done in 0.2 secs, train cost = 0.0582
# step 282 done in 0.2 secs, train cost = 0.0582
# step 283 done in 0.2 secs, train cost = 0.0582
# step 284 done in 0.3 secs, train cost = 0.0582
# step 285 done in 0.2 secs, train cost = 0.0582
# step 286 done in 0.2 secs, train cost = 0.0582
# step 287 done in 0.2 secs, train cost = 0.0582
# step 288 done in 0.7 secs, train cost = 0.0582
# step 289 done in 0.3 secs, train cost = 0.0582
# step 290 done in 0.4 secs, train cost = 0.0582
# step 291 done in 0.1 secs, train cost = 0.0582
# step 292 done in 0.4 secs, train cost = 0.0582
# step 293 done in 0.3 secs, train cost = 0.0582
# step 294 done in 0.2 secs, train cost = 0.0582
# step 295 done in 0.2 secs, train cost = 0.0582
# step 296 done in 0.2 secs, train cost = 0.0582
# step 297 done in 0.3 secs, train cost = 0.0582
# step 298 done in 0.4 secs, train cost = 0.0582
# step 299 done in 0.4 secs, train cost = 0.0582
# step 300 done in 0.2 secs, train cost = 0.0582
# step 301 done in 0.3 secs, train cost = 0.0582
# step 302 done in 0.2 secs, train cost = 0.0582
# step 303 done in 0.2 secs, train cost = 0.0582
# step 304 done in 0.2 secs, train cost = 0.0582
# step 305 done in 0.2 secs, train cost = 0.0582
# step 306 done in 0.2 secs, train cost = 0.0582
# step 307 done in 0.3 secs, train cost = 0.0582
# step 308 done in 0.2 secs, train cost = 0.0582
# step 309 done in 0.2 secs, train cost = 0.0582
# step 310 done in 0.2 secs, train cost = 0.0582
# step 311 done in 0.2 secs, train cost = 0.0582
# step 312 done in 0.3 secs, train cost = 0.0582
# step 313 done in 0.2 secs, train cost = 0.0582
# step 314 done in 0.3 secs, train cost = 0.0582
# step 315 done in 0.3 secs, train cost = 0.0582
# step 316 done in 0.2 secs, train cost = 0.0582
# step 317 done in 0.2 secs, train cost = 0.0582
# step 318 done in 0.2 secs, train cost = 0.0582
# step 319 done in 0.2 secs, train cost = 0.0582
# step 320 done in 0.2 secs, train cost = 0.0582
# step 321 done in 0.2 secs, train cost = 0.0582
# step 322 done in 0.2 secs, train cost = 0.0582
# step 323 done in 0.2 secs, train cost = 0.0582
# step 324 done in 0.2 secs, train cost = 0.0582
# step 325 done in 0.2 secs, train cost = 0.0582
# step 326 done in 0.2 secs, train cost = 0.0582
# step 327 done in 0.2 secs, train cost = 0.0582
# step 328 done in 0.2 secs, train cost = 0.0582
# step 329 done in 0.2 secs, train cost = 0.0582
# step 330 done in 0.2 secs, train cost = 0.0582
# step 331 done in 0.2 secs, train cost = 0.0582
# step 332 done in 0.2 secs, train cost = 0.0582
# step 333 done in 0.2 secs, train cost = 0.0582
# step 334 done in 0.2 secs, train cost = 0.0582
# step 335 done in 0.2 secs, train cost = 0.0582
# step 336 done in 0.2 secs, train cost = 0.0582
# step 337 done in 0.2 secs, train cost = 0.0582
# step 338 done in 0.2 secs, train cost = 0.0582
# step 339 done in 0.2 secs, train cost = 0.0582
# step 340 done in 0.2 secs, train cost = 0.0582
# step 341 done in 0.2 secs, train cost = 0.0582
# step 342 done in 0.2 secs, train cost = 0.0582
# step 343 done in 0.2 secs, train cost = 0.0582
# step 344 done in 0.2 secs, train cost = 0.0582
# step 345 done in 0.2 secs, train cost = 0.0582
# step 346 done in 0.2 secs, train cost = 0.0582
# step 347 done in 0.2 secs, train cost = 0.0582
# step 348 done in 0.2 secs, train cost = 0.0582
# step 349 done in 0.2 secs, train cost = 0.0582
# step 350 done in 0.2 secs, train cost = 0.0582
# step 351 done in 0.2 secs, train cost = 0.0582
# step 352 done in 0.2 secs, train cost = 0.0582
# step 353 done in 0.1 secs, train cost = 0.0582
# step 354 done in 0.2 secs, train cost = 0.0582
# step 355 done in 0.2 secs, train cost = 0.0582
# step 356 done in 0.2 secs, train cost = 0.0582
# step 357 done in 0.2 secs, train cost = 0.0582
# step 358 done in 0.2 secs, train cost = 0.0582
# step 359 done in 0.2 secs, train cost = 0.0582
# step 360 done in 0.2 secs, train cost = 0.0582
# step 361 done in 0.3 secs, train cost = 0.0582
# step 362 done in 0.1 secs, train cost = 0.0582
# step 363 done in 0.2 secs, train cost = 0.0582
# step 364 done in 0.2 secs, train cost = 0.0582
# step 365 done in 0.2 secs, train cost = 0.0582
# step 366 done in 0.2 secs, train cost = 0.0582
# step 367 done in 0.2 secs, train cost = 0.0582
# step 368 done in 0.2 secs, train cost = 0.0582
# step 369 done in 0.2 secs, train cost = 0.0582
# step 370 done in 0.1 secs, train cost = 0.0582
# step 371 done in 0.2 secs, train cost = 0.0582
# step 372 done in 0.2 secs, train cost = 0.0582
# step 373 done in 0.2 secs, train cost = 0.0582
# step 374 done in 0.2 secs, train cost = 0.0582
# step 375 done in 0.2 secs, train cost = 0.0582
# step 376 done in 0.2 secs, train cost = 0.0582
# step 377 done in 0.2 secs, train cost = 0.0582
# step 378 done in 0.2 secs, train cost = 0.0582
# step 379 done in 0.2 secs, train cost = 0.0582
# step 380 done in 0.2 secs, train cost = 0.0582
# step 381 done in 0.2 secs, train cost = 0.0582
# step 382 done in 0.2 secs, train cost = 0.0582
# step 383 done in 0.2 secs, train cost = 0.0582
# step 384 done in 0.2 secs, train cost = 0.0582
# step 385 done in 0.2 secs, train cost = 0.0582
# step 386 done in 0.2 secs, train cost = 0.0582
# step 387 done in 0.2 secs, train cost = 0.0582
# step 388 done in 0.2 secs, train cost = 0.0582
# step 389 done in 0.2 secs, train cost = 0.0582
# step 390 done in 0.2 secs, train cost = 0.0582
# step 391 done in 0.2 secs, train cost = 0.0582
# step 392 done in 0.2 secs, train cost = 0.0582
# step 393 done in 0.2 secs, train cost = 0.0582
# step 394 done in 0.2 secs, train cost = 0.0582
# step 395 done in 0.2 secs, train cost = 0.0582
# step 396 done in 0.2 secs, train cost = 0.0582
# step 397 done in 0.1 secs, train cost = 0.0582
# step 398 done in 0.2 secs, train cost = 0.0582
# step 399 done in 0.2 secs, train cost = 0.0582
# step 400 done in 0.2 secs, train cost = 0.0582
# step 401 done in 0.2 secs, train cost = 0.0582
# step 402 done in 0.2 secs, train cost = 0.0582
# step 403 done in 0.2 secs, train cost = 0.0582
# step 404 done in 0.2 secs, train cost = 0.0582
# step 405 done in 0.2 secs, train cost = 0.0582
# step 406 done in 0.2 secs, train cost = 0.0582
# step 407 done in 0.2 secs, train cost = 0.0582
# step 408 done in 0.2 secs, train cost = 0.0582
# step 409 done in 0.2 secs, train cost = 0.0582
# step 410 done in 0.2 secs, train cost = 0.0582
# step 411 done in 0.2 secs, train cost = 0.0582
# step 412 done in 0.2 secs, train cost = 0.0582
# step 413 done in 0.2 secs, train cost = 0.0582
# step 414 done in 0.2 secs, train cost = 0.0582
# step 415 done in 0.2 secs, train cost = 0.0582
# step 416 done in 0.2 secs, train cost = 0.0582
# step 417 done in 0.2 secs, train cost = 0.0582
# step 418 done in 0.2 secs, train cost = 0.0582
# step 419 done in 0.2 secs, train cost = 0.0582
# step 420 done in 0.2 secs, train cost = 0.0582
# step 421 done in 0.2 secs, train cost = 0.0582
# step 422 done in 0.2 secs, train cost = 0.0582
# step 423 done in 0.2 secs, train cost = 0.0582
# step 424 done in 0.1 secs, train cost = 0.0582
# step 425 done in 0.2 secs, train cost = 0.0582
# step 426 done in 0.2 secs, train cost = 0.0582
# step 427 done in 0.2 secs, train cost = 0.0582
# step 428 done in 0.2 secs, train cost = 0.0582
# step 429 done in 0.2 secs, train cost = 0.0582
# step 430 done in 0.2 secs, train cost = 0.0582
# step 431 done in 0.2 secs, train cost = 0.0582
# step 432 done in 0.2 secs, train cost = 0.0582
# step 433 done in 0.2 secs, train cost = 0.0582
# step 434 done in 0.2 secs, train cost = 0.0582
# step 435 done in 0.2 secs, train cost = 0.0582
# step 436 done in 0.2 secs, train cost = 0.0582
# step 437 done in 0.2 secs, train cost = 0.0582
# step 438 done in 0.2 secs, train cost = 0.0582
# step 439 done in 0.2 secs, train cost = 0.0582
# step 440 done in 0.2 secs, train cost = 0.0582
# step 441 done in 0.1 secs, train cost = 0.0581
# step 442 done in 0.2 secs, train cost = 0.0581
# step 443 done in 0.2 secs, train cost = 0.0581
# step 444 done in 0.2 secs, train cost = 0.0581
# step 445 done in 0.2 secs, train cost = 0.0581
# step 446 done in 0.2 secs, train cost = 0.0581
# step 447 done in 0.2 secs, train cost = 0.0581
# step 448 done in 0.2 secs, train cost = 0.0581
# step 449 done in 0.2 secs, train cost = 0.0581
# step 450 done in 0.2 secs, train cost = 0.0581
# step 451 done in 0.1 secs, train cost = 0.0581
# step 452 done in 0.2 secs, train cost = 0.0581
# step 453 done in 0.2 secs, train cost = 0.0581
# step 454 done in 0.2 secs, train cost = 0.0581
# step 455 done in 0.2 secs, train cost = 0.0581
# step 456 done in 0.2 secs, train cost = 0.0581
# step 457 done in 0.2 secs, train cost = 0.0581
# step 458 done in 0.2 secs, train cost = 0.0581
# step 459 done in 0.1 secs, train cost = 0.0581
# step 460 done in 0.2 secs, train cost = 0.0581
# step 461 done in 0.2 secs, train cost = 0.0581
# step 462 done in 0.2 secs, train cost = 0.0581
# step 463 done in 0.2 secs, train cost = 0.0581
# step 464 done in 0.2 secs, train cost = 0.0581
# step 465 done in 0.2 secs, train cost = 0.0581
# step 466 done in 0.2 secs, train cost = 0.0581
# step 467 done in 0.2 secs, train cost = 0.0581
# step 468 done in 0.2 secs, train cost = 0.0581
# step 469 done in 0.2 secs, train cost = 0.0581
# step 470 done in 0.2 secs, train cost = 0.0581
# step 471 done in 0.2 secs, train cost = 0.0581
# step 472 done in 0.2 secs, train cost = 0.0581
# step 473 done in 0.2 secs, train cost = 0.0581
# step 474 done in 0.2 secs, train cost = 0.0581
# step 475 done in 0.2 secs, train cost = 0.0581
# step 476 done in 0.2 secs, train cost = 0.0581
# step 477 done in 0.1 secs, train cost = 0.0581
# step 478 done in 0.2 secs, train cost = 0.0581
# step 479 done in 0.2 secs, train cost = 0.0581
# step 480 done in 0.2 secs, train cost = 0.0581
# step 481 done in 0.2 secs, train cost = 0.0581
# step 482 done in 0.2 secs, train cost = 0.0581
# step 483 done in 0.2 secs, train cost = 0.0581
# step 484 done in 0.2 secs, train cost = 0.0581
# step 485 done in 0.2 secs, train cost = 0.0581
# step 486 done in 0.2 secs, train cost = 0.0581
# step 487 done in 0.1 secs, train cost = 0.0581
# step 488 done in 0.2 secs, train cost = 0.0581
# step 489 done in 0.2 secs, train cost = 0.0581
# step 490 done in 0.2 secs, train cost = 0.0581
# step 491 done in 0.2 secs, train cost = 0.0581
# step 492 done in 0.2 secs, train cost = 0.0581
# step 493 done in 0.2 secs, train cost = 0.0581
# step 494 done in 0.2 secs, train cost = 0.0581
# step 495 done in 0.1 secs, train cost = 0.0581
# step 496 done in 0.2 secs, train cost = 0.0581
# step 497 done in 0.2 secs, train cost = 0.0581
# step 498 done in 0.2 secs, train cost = 0.0581
# step 499 done in 0.2 secs, train cost = 0.0581
# step 500 done in 0.2 secs, train cost = 0.0581
# step 501 done in 0.2 secs, train cost = 0.0581
# finished all 500 steps

# %%
### plot original state data and system model approximation

# evaluate output of learned model
opt_weights = w_hist[-1]
print(opt_weights)

#system_model1 = opt_weights[0] + opt_weights[1]*states[0,0:-1] + opt_weights[2]*actions

T = states.shape[1]
system_model = np.zeros(T-1)
    
for ii in range(1,T-1):
    system_model[ii] = opt_weights[0] + opt_weights[1]*system_model[ii-1] + opt_weights[2]*actions[0,ii]


import matplotlib.pyplot as plt
from matplotlib import gridspec
import copy

# initialize figure
fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(111); 

# plot data
ax1.plot(np.arange(np.size(system_model)),system_model.flatten(),c = 'cyan',linewidth = 1.5,label = 'System Model',zorder = 2)
ax1.plot(np.arange(np.size(states)),states.flatten(),c = 'black',linewidth = 1.5,label = 'Original States',zorder = 1)

# label axes and title
ax1.set_title('Output Sequences')
ax1.set_xlabel('Step')

plt.show()
# Out:
# [[0.94216013]
#  [0.93338606]
#  [0.03797763]]
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 2: </span>  Train an unregularized PID controller for the cruise control problem

# %% [markdown]
# In this exercise you will tune the parameters of a PID controller automatically so that the system model trained in the previous exercise matches the example set point sequence shown below.  Note: you need to have finished the previous exercise in order to properly solve this one!

# %%
# load in set point sequence
csvname = 'datasets/cruise_setpoints.csv'
set_points = np.loadtxt(csvname,delimiter = ',')[np.newaxis,:]

# plot set point sequence
plotter.plot_setpoints(set_points)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Implement a `Pythonic` version of the PID controller Least Squares cost function discussed in the [course notes](https://www.dropbox.com/s/m6456ze0fd8kaf8/system_identification_pid_notes.pdf?dl=0).  You should be able to learn an action / state sequence pair so that your system model responds fairly well to the input set point sequence.  The image below shows the results of an action/state sequence pair learned by a fully tuned PID controller.  The top panel shows the set point sequence in dashed black, with the state sequence defined by the controller in blue.  The bottom panel shows the corresponding action sequence defined by the controller.
#
# A few notes:
# - For this exercise you need not worry about regularizing either the state or action sequences when training the controller - simply tune it as best as you can.
#
#
# - Even though a PID controller is technically a Recurrent Network (which can be slow to train), here we only deal with a fairly small dataset of set points and there only 4 parameters to tune - so you can apply the simplest kind of first order algorithm to properly minimize the controller cost (e.g., a full batch gradient descent optimizer).

# %% [markdown]
# <figure>
# <p>
# <img src= 'images/PID_1.png' width="150%" height="150%" alt=""/>
# </p>
# </figure>

# %%
# inner loop gradient descent function to tune weights

V = [0.8188113,0.93756861,0.03687846] # optimal weights for system model, from problem 1


def g(w,a_train,s_train):
    ''' 
    Least squares cost function 

    Incorporating PID weights into system model

    '''
    
    J = 0
    T = set_points.shape[1]
    dt = 1 # time is given in "steps"
    
    Perror = 0
    Ierror = 0
    Derror = 0
    last_error = 0
    
    action = 0
    state = 0    
    last_action = 0
    last_state = 0
    
    for ii in range(1,T-1):
        
        Perror = s_train[0,ii] - last_state
        Ierror = Ierror + (dt)*Perror
        Derror = (Perror - last_error) / dt
        
        action = w[0] + w[1]*Perror + w[2]*Ierror + w[3]*Derror # current action from PID controller
        state = V[0] + V[1]*last_state + V[2]*last_action # current state from system model
              
        J = J + (V[0] + V[1]*state + V[2]*action - s_train[0,ii+1])**2
        
        last_state = state
        last_action = action
        last_error = Perror
    
    J = J/(T-1)
    
    return J    

# optimize PID weights
alpha = 0.2
max_its = 250
verbose = True
PIDweights = np.asarray([0.0,20.0,1.0,1.0])

PIDw_hist, train_hist = optimizers.gradient_descent(g,PIDweights,[],set_points,alpha,max_its,verbose)

print(PIDw_hist[-1])
# Out:
# step 2 done in 0.3 secs, train cost = 8.3796
# step 3 done in 0.3 secs, train cost = 7.5704
# step 4 done in 0.2 secs, train cost = 7.4094
# step 5 done in 0.2 secs, train cost = 8.4462
# step 6 done in 0.2 secs, train cost = 7.2274
# step 7 done in 0.2 secs, train cost = 6.6816
# step 8 done in 0.3 secs, train cost = 6.4296
# step 9 done in 0.2 secs, train cost = 6.2945
# step 10 done in 0.2 secs, train cost = 6.1743
# step 11 done in 0.4 secs, train cost = 6.0635
# step 12 done in 0.3 secs, train cost = 5.9736
# step 13 done in 0.3 secs, train cost = 5.8562
# step 14 done in 0.2 secs, train cost = 5.7687
# step 15 done in 0.2 secs, train cost = 5.6875
# step 16 done in 0.2 secs, train cost = 5.6121
# step 17 done in 0.2 secs, train cost = 5.5417
# step 18 done in 0.3 secs, train cost = 5.4758
# step 19 done in 0.2 secs, train cost = 5.4139
# step 20 done in 0.2 secs, train cost = 5.3556
# step 21 done in 0.2 secs, train cost = 5.3005
# step 22 done in 0.4 secs, train cost = 5.2481
# step 23 done in 0.4 secs, train cost = 5.1981
# step 24 done in 0.2 secs, train cost = 5.1501
# step 25 done in 0.2 secs, train cost = 5.104
# step 26 done in 0.2 secs, train cost = 5.0596
# step 27 done in 0.3 secs, train cost = 5.0166
# step 28 done in 0.2 secs, train cost = 4.9753
# step 29 done in 0.2 secs, train cost = 4.9354
# step 30 done in 0.2 secs, train cost = 4.8971
# step 31 done in 0.2 secs, train cost = 4.8602
# step 32 done in 0.3 secs, train cost = 4.8248
# step 33 done in 0.2 secs, train cost = 4.7907
# step 34 done in 0.2 secs, train cost = 4.758
# step 35 done in 0.3 secs, train cost = 4.7265
# step 36 done in 0.2 secs, train cost = 4.6962
# step 37 done in 0.3 secs, train cost = 4.6671
# step 38 done in 0.2 secs, train cost = 4.6391
# step 39 done in 0.2 secs, train cost = 4.6121
# step 40 done in 0.2 secs, train cost = 4.5861
# step 41 done in 0.2 secs, train cost = 4.561
# step 42 done in 0.3 secs, train cost = 4.5368
# step 43 done in 0.2 secs, train cost = 4.5135
# step 44 done in 0.2 secs, train cost = 4.4911
# step 45 done in 0.2 secs, train cost = 4.4694
# step 46 done in 0.3 secs, train cost = 4.4484
# step 47 done in 0.4 secs, train cost = 4.4282
# step 48 done in 0.2 secs, train cost = 4.4087
# step 49 done in 0.2 secs, train cost = 4.3898
# step 50 done in 0.2 secs, train cost = 4.3715
# step 51 done in 0.2 secs, train cost = 4.3538
# step 52 done in 0.3 secs, train cost = 4.3367
# step 53 done in 0.2 secs, train cost = 4.3202
# step 54 done in 0.2 secs, train cost = 4.3041
# step 55 done in 0.2 secs, train cost = 4.2886
# step 56 done in 0.2 secs, train cost = 4.2736
# step 57 done in 0.3 secs, train cost = 4.259
# step 58 done in 0.2 secs, train cost = 4.2448
# step 59 done in 0.2 secs, train cost = 4.2311
# step 60 done in 0.2 secs, train cost = 4.2178
# step 61 done in 0.2 secs, train cost = 4.2049
# step 62 done in 0.3 secs, train cost = 4.1923
# step 63 done in 0.2 secs, train cost = 4.1801
# step 64 done in 0.2 secs, train cost = 4.1683
# step 65 done in 0.2 secs, train cost = 4.1568
# step 66 done in 0.2 secs, train cost = 4.1456
# step 67 done in 0.3 secs, train cost = 4.1347
# step 68 done in 0.2 secs, train cost = 4.1241
# step 69 done in 0.2 secs, train cost = 4.1138
# step 70 done in 0.2 secs, train cost = 4.1038
# step 71 done in 0.2 secs, train cost = 4.094
# step 72 done in 0.3 secs, train cost = 4.0845
# step 73 done in 0.2 secs, train cost = 4.0752
# step 74 done in 0.2 secs, train cost = 4.0662
# step 75 done in 0.2 secs, train cost = 4.0574
# step 76 done in 0.2 secs, train cost = 4.0489
# step 77 done in 0.3 secs, train cost = 4.0405
# step 78 done in 0.2 secs, train cost = 4.0324
# step 79 done in 0.2 secs, train cost = 4.0244
# step 80 done in 0.2 secs, train cost = 4.0167
# step 81 done in 0.3 secs, train cost = 4.0091
# step 82 done in 0.2 secs, train cost = 4.0017
# step 83 done in 0.2 secs, train cost = 3.9945
# step 84 done in 0.2 secs, train cost = 3.9875
# step 85 done in 0.2 secs, train cost = 3.9806
# step 86 done in 0.3 secs, train cost = 3.9739
# step 87 done in 0.2 secs, train cost = 3.9673
# step 88 done in 0.2 secs, train cost = 3.9609
# step 89 done in 0.2 secs, train cost = 3.9546
# step 90 done in 0.2 secs, train cost = 3.9485
# step 91 done in 0.3 secs, train cost = 3.9425
# step 92 done in 0.2 secs, train cost = 3.9366
# step 93 done in 0.2 secs, train cost = 3.9309
# step 94 done in 0.2 secs, train cost = 3.9253
# step 95 done in 0.2 secs, train cost = 3.9198
# step 96 done in 0.3 secs, train cost = 3.9144
# step 97 done in 0.2 secs, train cost = 3.9091
# step 98 done in 0.2 secs, train cost = 3.904
# step 99 done in 0.2 secs, train cost = 3.8989
# step 100 done in 0.2 secs, train cost = 3.894
# step 101 done in 0.3 secs, train cost = 3.8892
# step 102 done in 0.2 secs, train cost = 3.8844
# step 103 done in 0.2 secs, train cost = 3.8798
# step 104 done in 0.2 secs, train cost = 3.8752
# step 105 done in 0.3 secs, train cost = 3.8707
# step 106 done in 0.4 secs, train cost = 3.8664
# step 107 done in 0.2 secs, train cost = 3.8621
# step 108 done in 0.2 secs, train cost = 3.8579
# step 109 done in 0.2 secs, train cost = 3.8538
# step 110 done in 0.2 secs, train cost = 3.8497
# step 111 done in 0.3 secs, train cost = 3.8457
# step 112 done in 0.3 secs, train cost = 3.8419
# step 113 done in 0.3 secs, train cost = 3.838
# step 114 done in 0.3 secs, train cost = 3.8343
# step 115 done in 0.3 secs, train cost = 3.8306
# step 116 done in 0.3 secs, train cost = 3.827
# step 117 done in 0.2 secs, train cost = 3.8235
# step 118 done in 0.2 secs, train cost = 3.82
# step 119 done in 0.2 secs, train cost = 3.8166
# step 120 done in 0.2 secs, train cost = 3.8132
# step 121 done in 0.3 secs, train cost = 3.8099
# step 122 done in 0.2 secs, train cost = 3.8067
# step 123 done in 0.2 secs, train cost = 3.8035
# step 124 done in 0.2 secs, train cost = 3.8004
# step 125 done in 0.2 secs, train cost = 3.7974
# step 126 done in 0.3 secs, train cost = 3.7944
# step 127 done in 0.2 secs, train cost = 3.7914
# step 128 done in 0.2 secs, train cost = 3.7885
# step 129 done in 0.2 secs, train cost = 3.7857
# step 130 done in 0.2 secs, train cost = 3.7829
# step 131 done in 0.3 secs, train cost = 3.7801
# step 132 done in 0.2 secs, train cost = 3.7774
# step 133 done in 0.2 secs, train cost = 3.7748
# step 134 done in 0.2 secs, train cost = 3.7721
# step 135 done in 0.3 secs, train cost = 3.7696
# step 136 done in 0.2 secs, train cost = 3.767
# step 137 done in 0.2 secs, train cost = 3.7646
# step 138 done in 0.2 secs, train cost = 3.7621
# step 139 done in 0.2 secs, train cost = 3.7597
# step 140 done in 0.3 secs, train cost = 3.7574
# step 141 done in 0.2 secs, train cost = 3.755
# step 142 done in 0.2 secs, train cost = 3.7528
# step 143 done in 0.2 secs, train cost = 3.7505
# step 144 done in 0.2 secs, train cost = 3.7483
# step 145 done in 0.3 secs, train cost = 3.7461
# step 146 done in 0.2 secs, train cost = 3.744
# step 147 done in 0.2 secs, train cost = 3.7419
# step 148 done in 0.2 secs, train cost = 3.7398
# step 149 done in 0.2 secs, train cost = 3.7378
# step 150 done in 0.3 secs, train cost = 3.7358
# step 151 done in 0.2 secs, train cost = 3.7338
# step 152 done in 0.2 secs, train cost = 3.7319
# step 153 done in 0.2 secs, train cost = 3.73
# step 154 done in 0.2 secs, train cost = 3.7281
# step 155 done in 0.3 secs, train cost = 3.7263
# step 156 done in 0.2 secs, train cost = 3.7245
# step 157 done in 0.2 secs, train cost = 3.7227
# step 158 done in 0.3 secs, train cost = 3.7209
# step 159 done in 0.2 secs, train cost = 3.7192
# step 160 done in 0.3 secs, train cost = 3.7175
# step 161 done in 0.2 secs, train cost = 3.7158
# step 162 done in 0.2 secs, train cost = 3.7142
# step 163 done in 0.2 secs, train cost = 3.7126
# step 164 done in 0.2 secs, train cost = 3.711
# step 165 done in 0.3 secs, train cost = 3.7094
# step 166 done in 0.2 secs, train cost = 3.7078
# step 167 done in 0.2 secs, train cost = 3.7063
# step 168 done in 0.2 secs, train cost = 3.7048
# step 169 done in 0.2 secs, train cost = 3.7033
# step 170 done in 0.3 secs, train cost = 3.7019
# step 171 done in 0.2 secs, train cost = 3.7005
# step 172 done in 0.2 secs, train cost = 3.6991
# step 173 done in 0.2 secs, train cost = 3.6977
# step 174 done in 0.2 secs, train cost = 3.6963
# step 175 done in 0.3 secs, train cost = 3.695
# step 176 done in 0.2 secs, train cost = 3.6936
# step 177 done in 0.2 secs, train cost = 3.6923
# step 178 done in 0.2 secs, train cost = 3.6911
# step 179 done in 0.2 secs, train cost = 3.6898
# step 180 done in 0.3 secs, train cost = 3.6886
# step 181 done in 0.2 secs, train cost = 3.6873
# step 182 done in 0.2 secs, train cost = 3.6861
# step 183 done in 0.2 secs, train cost = 3.6849
# step 184 done in 0.2 secs, train cost = 3.6838
# step 185 done in 0.3 secs, train cost = 3.6826
# step 186 done in 0.2 secs, train cost = 3.6815
# step 187 done in 0.2 secs, train cost = 3.6804
# step 188 done in 0.2 secs, train cost = 3.6793
# step 189 done in 0.3 secs, train cost = 3.6782
# step 190 done in 0.3 secs, train cost = 3.6771
# step 191 done in 0.3 secs, train cost = 3.6761
# step 192 done in 0.3 secs, train cost = 3.675
# step 193 done in 0.3 secs, train cost = 3.674
# step 194 done in 0.3 secs, train cost = 3.673
# step 195 done in 0.2 secs, train cost = 3.672
# step 196 done in 0.3 secs, train cost = 3.6711
# step 197 done in 0.2 secs, train cost = 3.6701
# step 198 done in 0.2 secs, train cost = 3.6692
# step 199 done in 0.3 secs, train cost = 3.6682
# step 200 done in 0.2 secs, train cost = 3.6673
# step 201 done in 0.2 secs, train cost = 3.6664
# step 202 done in 0.3 secs, train cost = 3.6655
# step 203 done in 0.3 secs, train cost = 3.6646
# step 204 done in 0.3 secs, train cost = 3.6638
# step 205 done in 0.3 secs, train cost = 3.6629
# step 206 done in 0.2 secs, train cost = 3.6621
# step 207 done in 0.3 secs, train cost = 3.6613
# step 208 done in 0.2 secs, train cost = 3.6605
# step 209 done in 0.3 secs, train cost = 3.6597
# step 210 done in 0.3 secs, train cost = 3.6589
# step 211 done in 0.2 secs, train cost = 3.6581
# step 212 done in 0.2 secs, train cost = 3.6573
# step 213 done in 0.2 secs, train cost = 3.6566
# step 214 done in 0.3 secs, train cost = 3.6559
# step 215 done in 0.3 secs, train cost = 3.6551
# step 216 done in 0.3 secs, train cost = 3.6544
# step 217 done in 0.2 secs, train cost = 3.6537
# step 218 done in 0.2 secs, train cost = 3.653
# step 219 done in 0.3 secs, train cost = 3.6523
# step 220 done in 0.2 secs, train cost = 3.6516
# step 221 done in 0.3 secs, train cost = 3.651
# step 222 done in 0.3 secs, train cost = 3.6503
# step 223 done in 0.2 secs, train cost = 3.6497
# step 224 done in 0.3 secs, train cost = 3.649
# step 225 done in 0.2 secs, train cost = 3.6484
# step 226 done in 0.3 secs, train cost = 3.6478
# step 227 done in 0.2 secs, train cost = 3.6472
# step 228 done in 0.2 secs, train cost = 3.6466
# step 229 done in 0.3 secs, train cost = 3.646
# step 230 done in 0.3 secs, train cost = 3.6454
# step 231 done in 0.3 secs, train cost = 3.6448
# step 232 done in 0.2 secs, train cost = 3.6442
# step 233 done in 0.2 secs, train cost = 3.6437
# step 234 done in 0.3 secs, train cost = 3.6431
# step 235 done in 0.3 secs, train cost = 3.6426
# step 236 done in 0.2 secs, train cost = 3.6421
# step 237 done in 0.2 secs, train cost = 3.6415
# step 238 done in 0.2 secs, train cost = 3.641
# step 239 done in 0.3 secs, train cost = 3.6405
# step 240 done in 0.2 secs, train cost = 3.64
# step 241 done in 0.2 secs, train cost = 3.6395
# step 242 done in 0.3 secs, train cost = 3.639
# step 243 done in 0.3 secs, train cost = 3.6385
# step 244 done in 0.3 secs, train cost = 3.6381
# step 245 done in 0.2 secs, train cost = 3.6376
# step 246 done in 0.3 secs, train cost = 3.6371
# step 247 done in 0.2 secs, train cost = 3.6367
# step 248 done in 0.3 secs, train cost = 3.6362
# step 249 done in 0.2 secs, train cost = 3.6358
# step 250 done in 0.2 secs, train cost = 3.6354
# step 251 done in 0.2 secs, train cost = 3.6349
# finished all 250 steps
# [-0.23427828 11.28757363  0.63116257  6.04966396]

# %%
# use optimized weights to calculate response to set points trajectory
opt_PIDw = [-0.23427828, 11.28757363,  0.63116257,  6.04966396] # from output of optimization

T = set_points.shape[1]

states = np.zeros(T)
actions = np.zeros(T)

dt = 1 # time is given in "steps"
    
Perror = 0
Ierror = 0
Derror = 0
last_error = 0
 
last_action = 0
last_state = 0

for ii in range(1,T-1):

    Perror = set_points[0,ii] - last_state
    Ierror = Ierror + (dt)*Perror
    Derror = (Perror - last_error) / dt

    actions[ii] = opt_PIDw[0] + opt_PIDw[1]*Perror + opt_PIDw[2]*Ierror + opt_PIDw[3]*Derror # current action from PID controller
    states[ii+1] = V[0] + V[1]*last_state + V[2]*actions[ii] # current state from system model

    last_state = states[ii]
    last_action = actions[ii]
    last_error = Perror


# plot output of PID controller here
import matplotlib.pyplot as plt
from matplotlib import gridspec
import copy

# initialize figure
fig = plt.figure(figsize = (10,5))

# create subplot with 3 panels, plot input function in center plot
gs = gridspec.GridSpec(2,1) 
ax1 = plt.subplot(gs[1]); 
ax2 = plt.subplot(gs[0]);

ax1.plot(np.arange(np.size(actions)),actions.flatten(),c = 'lime',linewidth = 1.5)
ax2.plot(np.arange(np.size(states)),states.flatten(),c = 'cyan',linewidth = 1.5,label = 'States',zorder = 2)
ax2.plot(np.arange(np.size(set_points)),set_points.flatten(),c = 'k',linewidth = 1.5,label = 'Set Points',zorder = 1)

# label axes and title
ax1.set_title('input sequence')
ax1.set_xlabel('step')
ax2.set_title('output sequences')
ax2.set_xlabel('step')

# set viewing limits
s1min = np.min(copy.deepcopy(actions))
s1max = np.max(copy.deepcopy(actions))
s1gap = (s1max - s1min)*0.1
s1min -= s1gap
s1max += s1gap
ax1.set_ylim([s1min,s1max])

s2min = np.min(copy.deepcopy(states))
s2max = np.max(copy.deepcopy(states))
s2gap = (s2max - s2min)*0.1
s2min -= s2gap
s2max += s2gap
ax2.legend(loc = 1)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# #### <span style="color:#a50e3e;">Exercise 3: </span>  System identification on the two-tank problem

# %% [markdown]
# In this exercise you will create a system model - using a small snippet of cruise control data shown below.  This comes from a real life two-tanks experiment as shown on page 4 of the [course notes](https://www.dropbox.com/s/m6456ze0fd8kaf8/system_identification_pid_notes.pdf?dl=0).  The amount of water allowed into the top tank (per second) - the action sequence $a_t$ - is shown as the black curve in the bottom panel.  In the top panel the *upper* tank water level $s_{1,t}$ is shown in green, and the bottom tank level $s_{2,t}$ is shown in magenta.

# %%
# This code cell will not be shown in the HTML version of this notebook
# load series
data = np.loadtxt(datapath + 'cascaded_tanks_1.csv',delimiter = ',')
actions = data[0:1,1:]
states = data[1:,:]

# plot the test pair
plotter.plot_3fer(actions,states[0],states[1],plot_type = 'continuous')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# This system has two $s_{1,t}$ and $s_{2,t}$, hence the system model consists of an equation for each.  The upper tank level $s_{1,t}$ is dependent on its own history and - of course- the amount of water $a_t$ that is poured into it.  A simple linear system model for it then looks like
#
# \begin{equation}
# s_{1,t+1} = w_0 + w_1 s_{1,t} + w_2 a_t.
# \end{equation}
#
# Since we know that the upper tank drains into the lower one, the simplest sort of system model we can make for the lower tank level $s_{2,t}$ is that it is proportional to its prior value and that of the upper tank, as
#
# \begin{equation}
# s_{2,t+1} = w_3 + w_4s_{2,t} + w_5 s_{1,t}.
# \end{equation}
#
# Together - using the simplest model for this system we could think of - we have the following two system model equations
#
# \begin{array}
# \
# s_{1,t+1} = w_0 + w_1 s_{1,t} + w_2 a_t \\
# s_{2,t+1} = w_3 + w_4s_{2,t} + w_5 s_{1,t}.
# \end{array}

# %% [markdown]
# Tune the parameters of this system model $w_0$ through $w_5$ via minimizing a Least Squares cost function, using the data shown above for training (i.e., you need not cut off a chunk of it for validation - use it all for training).  Make sure to plot the fit your model provides on the training data.  You can see this exact system model fit to this exact dataset in the course notes - make sure your fit looks fairly similar.

# %%
# least squares function

def g(w,a_train,s_train):
    ''' Least squares cost function'''
    
    J1 = 0
    J2 = 0
    T = s_train.shape[1]
    
    for ii in range(1,T-1):
        J1 = J1 + (w[0] + w[1]*s_train[0,ii] + w[2]*a_train[0,ii] - s_train[0,ii+1])**2 # cost for first tank
        J2 = J2 + (w[3] + w[4]*s_train[1,ii] + w[5]*s_train[0,ii] - s_train[1,ii+1])**2

    J = (J1+J2)/(T-1)

    return J

# gradient descent

weights = np.random.rand(6,1)

alpha = 0.02
max_its = 50
verbose = True

w_hist,train_hist = optimizers.gradient_descent(g,weights,actions,states,alpha,max_its,verbose)

print(w_hist[-1])


### optimize weights for first tank, then second tank??
# Out:
# step 2 done in 0.7 secs, train cost = 0.4053
# step 3 done in 0.7 secs, train cost = 0.2945
# step 4 done in 0.8 secs, train cost = 0.2541
# step 5 done in 0.7 secs, train cost = 0.237
# step 6 done in 0.7 secs, train cost = 0.2278
# step 7 done in 0.6 secs, train cost = 0.2213
# step 8 done in 0.6 secs, train cost = 0.2157
# step 9 done in 0.6 secs, train cost = 0.2106
# step 10 done in 0.6 secs, train cost = 0.2057
# step 11 done in 0.6 secs, train cost = 0.201
# step 12 done in 0.6 secs, train cost = 0.1964
# step 13 done in 0.6 secs, train cost = 0.1919
# step 14 done in 0.7 secs, train cost = 0.1875
# step 15 done in 0.6 secs, train cost = 0.1833
# step 16 done in 0.6 secs, train cost = 0.1792
# step 17 done in 0.7 secs, train cost = 0.1751
# step 18 done in 0.6 secs, train cost = 0.1712
# step 19 done in 0.6 secs, train cost = 0.1674
# step 20 done in 0.8 secs, train cost = 0.1637
# step 21 done in 0.7 secs, train cost = 0.16
# step 22 done in 0.6 secs, train cost = 0.1565
# step 23 done in 0.6 secs, train cost = 0.153
# step 24 done in 0.6 secs, train cost = 0.1497
# step 25 done in 0.7 secs, train cost = 0.1464
# step 26 done in 0.6 secs, train cost = 0.1432
# step 27 done in 0.8 secs, train cost = 0.1401
# step 28 done in 0.6 secs, train cost = 0.137
# step 29 done in 0.6 secs, train cost = 0.134
# step 30 done in 0.7 secs, train cost = 0.1312
# step 31 done in 0.6 secs, train cost = 0.1283
# step 32 done in 0.6 secs, train cost = 0.1256
# step 33 done in 0.6 secs, train cost = 0.1229
# step 34 done in 0.7 secs, train cost = 0.1203
# step 35 done in 0.6 secs, train cost = 0.1177
# step 36 done in 0.6 secs, train cost = 0.1152
# step 37 done in 0.6 secs, train cost = 0.1128
# step 38 done in 0.7 secs, train cost = 0.1104
# step 39 done in 0.6 secs, train cost = 0.1081
# step 40 done in 0.7 secs, train cost = 0.1058
# step 41 done in 0.6 secs, train cost = 0.1036
# step 42 done in 0.6 secs, train cost = 0.1015
# step 43 done in 0.7 secs, train cost = 0.0993
# step 44 done in 0.6 secs, train cost = 0.0973
# step 45 done in 0.6 secs, train cost = 0.0953
# step 46 done in 0.6 secs, train cost = 0.0933
# step 47 done in 0.7 secs, train cost = 0.0914
# step 48 done in 0.6 secs, train cost = 0.0895
# step 49 done in 0.6 secs, train cost = 0.0877
# step 50 done in 0.6 secs, train cost = 0.0859
# step 51 done in 0.7 secs, train cost = 0.0842
# finished all 50 steps
# [[0.02725696]
#  [0.81328659]
#  [0.63271676]
#  [0.32916957]
#  [0.82521668]
#  [0.09578902]]

# %%
# use optimal weights to simulate system
opt_weights = [0.3580444,0.79067269,0.49115242,0.42099692,0.0647623,0.84640755]

T = states.shape[1]
system_model = np.zeros(states.shape)

for ii in range(1,T-1):
    system_model[0,ii+1] = opt_weights[0] + opt_weights[1]*system_model[0,ii] + opt_weights[2]*actions[0,ii]
    system_model[1,ii+1] = opt_weights[3] + opt_weights[4]*system_model[1,ii] + opt_weights[5]*system_model[0,ii]
    
# plot results
plotter.plot_3fer(actions,system_model[0],system_model[1],plot_type = 'continuous')

plotter.plot_3fer(actions,states[0],states[1],plot_type = 'continuous')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-6b6f46749cd5> in <module>()
#       6
#       7 for ii in range(1,T-1):
# ----> 8     system_model[0,ii+1] = opt_weights[0] + opt_weights[1]*system_model[0,ii] + opt_weights[2]*actions[ii]
#       9     system_model[1,ii+1] = opt_weights[3] + opt_weights[4]*system_model[1,ii] + opt_weights[5]*system_model[0,ii]
#      10
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
